# %%
l1 = [1, 3, 4, 2]
l1 = l1[2:]
print l1
# Out:
# [4, 2]

# %%
doc = ' TYT TYT fgh fvgb TYT'
num = doc.find('TYT')
last_num = -2
while num > -1:
    if num == last_num:
        break
    print num
    last_num = num
    num = num + 1 + doc[num + 1:].find('TYT')
# Out:
# 1
# 5
# 18

# %%
import os
tree = os.walk('all_TEX')
tree
# Out:
# <generator object walk at 0x105346910>

# %%
for text in tree:
    for j in text[2]:
        print(text[0]+'/'+j)
# Out:
# all_TEX/2011_1_5.tex
# all_TEX/2010_3_2.tex
# all_TEX/2011_1_10.tex
# all_TEX/2013_2_2.tex
# all_TEX/2011_3_7.tex
# all_TEX/2012_2_7.tex
# all_TEX/2009_3_1.tex
# all_TEX/2008_1_6.tex
# all_TEX/2012_4_1.tex
# all_TEX/2009_1_3.tex
# all_TEX/2008_3_4.tex
# all_TEX/2004_1_8.tex
# all_TEX/2014_1_8.tex
# all_TEX/2013_4_4.tex
# all_TEX/2013_4_5.tex
# all_TEX/2014_1_9.tex
# all_TEX/2004_1_9.tex
# all_TEX/2008_3_5.tex
# all_TEX/2009_1_2.tex
# all_TEX/2008_1_7.tex
# all_TEX/2012_2_6.tex
# all_TEX/2010_1_1.tex
# all_TEX/2011_3_6.tex
# all_TEX/2006_4_8.tex
# all_TEX/2013_2_3.tex
# all_TEX/2010_3_3.tex
# all_TEX/2011_1_4.tex
# all_TEX/2010_3_1.tex
# all_TEX/2011_1_6.tex
# all_TEX/2013_2_1.tex
# all_TEX/2010_1_3.tex
# all_TEX/2011_3_4.tex
# all_TEX/2012_2_4.tex
# all_TEX/2008_1_5.tex
# all_TEX/2009_3_2.tex
# all_TEX/2012_4_2.tex
# all_TEX/2008_3_7.tex
# all_TEX/2013_4_7.tex
# all_TEX/2013_4_6.tex
# all_TEX/2009_1_1.tex
# all_TEX/2008_3_6.tex
# all_TEX/2012_4_3.tex
# all_TEX/2004_3_8.tex
# all_TEX/2014_3_8.tex
# all_TEX/2009_3_3.tex
# all_TEX/2008_1_4.tex
# all_TEX/2012_2_5.tex
# all_TEX/2011_3_5.tex
# all_TEX/2012_2_10.tex
# all_TEX/2010_1_2.tex
# all_TEX/2013_2_10.tex
# all_TEX/2011_1_7.tex
# all_TEX/2010_3_4.tex
# all_TEX/2011_1_3.tex
# all_TEX/2013_2_4.tex
# all_TEX/2010_1_6.tex
# all_TEX/2011_3_1.tex
# all_TEX/2012_2_1.tex
# all_TEX/2014_4_10.tex
# all_TEX/2009_3_7.tex
# all_TEX/2012_4_7.tex
# all_TEX/2005_3_9.tex
# all_TEX/2015_3_9.tex
# all_TEX/2008_3_2.tex
# all_TEX/2009_1_5.tex
# all_TEX/2006_2_9.tex
# all_TEX/2016_2_9.tex
# all_TEX/2013_4_2.tex
# all_TEX/2013_4_3.tex
# all_TEX/2016_2_8.tex
# all_TEX/2006_2_8.tex
# all_TEX/2009_1_4.tex
# all_TEX/2008_3_3.tex
# all_TEX/2015_3_8.tex
# all_TEX/2005_3_8.tex
# all_TEX/2012_4_6.tex
# all_TEX/2009_3_6.tex
# all_TEX/2008_1_1.tex
# all_TEX/2014_4_11.tex
# all_TEX/2013_2_5.tex
# all_TEX/2011_1_2.tex
# all_TEX/2010_3_5.tex
# all_TEX/2010_3_7.tex
# all_TEX/2013_2_7.tex
# all_TEX/2011_3_2.tex
# all_TEX/2010_1_5.tex
# all_TEX/2012_2_2.tex
# all_TEX/2015_1_8.tex
# all_TEX/2009_3_4.tex
# all_TEX/2008_1_3.tex
# all_TEX/2012_4_4.tex
# all_TEX/2009_1_6.tex
# all_TEX/2008_3_1.tex
# all_TEX/2013_4_1.tex
# all_TEX/2012_4_5.tex
# all_TEX/2005_2_10.tex
# all_TEX/2008_1_2.tex
# all_TEX/2009_3_5.tex
# all_TEX/2015_1_9.tex
# all_TEX/2012_2_3.tex
# all_TEX/2010_1_4.tex
# all_TEX/2011_3_3.tex
# all_TEX/2013_2_6.tex
# all_TEX/2010_3_6.tex
# all_TEX/2011_1_1.tex
# all_TEX/2008_2_7.tex
# all_TEX/2010_4_7.tex
# all_TEX/2011_4_2.tex
# all_TEX/2009_2_2.tex
# all_TEX/2014_2_9.tex
# all_TEX/2009_4_4.tex
# all_TEX/2011_2_4.tex
# all_TEX/2013_1_3.tex
# all_TEX/2012_3_4.tex
# all_TEX/2010_2_1.tex
# all_TEX/2012_4_10.tex
# all_TEX/2013_4_10.tex
# all_TEX/2008_4_1.tex
# all_TEX/2013_3_1.tex
# all_TEX/2012_1_6.tex
# all_TEX/2012_1_7.tex
# all_TEX/2013_4_11.tex
# all_TEX/2012_4_11.tex
# all_TEX/2012_3_5.tex
# all_TEX/2013_1_2.tex
# all_TEX/2011_2_5.tex
# all_TEX/2009_4_5.tex
# all_TEX/2004_2_8.tex
# all_TEX/2014_2_8.tex
# all_TEX/2009_2_3.tex
# all_TEX/2011_4_3.tex
# all_TEX/2010_4_6.tex
# all_TEX/2008_2_6.tex
# all_TEX/2010_4_4.tex
# all_TEX/2008_2_4.tex
# all_TEX/2009_2_1.tex
# all_TEX/2011_4_1.tex
# all_TEX/2011_2_7.tex
# all_TEX/2009_4_7.tex
# all_TEX/2012_3_7.tex
# all_TEX/2008_4_2.tex
# all_TEX/2010_2_2.tex
# all_TEX/2005_4_9.tex
# all_TEX/2015_4_9.tex
# all_TEX/2012_1_5.tex
# all_TEX/2013_3_2.tex
# all_TEX/2013_3_3.tex
# all_TEX/2012_1_4.tex
# all_TEX/2015_4_8.tex
# all_TEX/2005_4_8.tex
# all_TEX/2012_4_12.tex
# all_TEX/2010_2_3.tex
# all_TEX/2008_4_3.tex
# all_TEX/2013_4_12.tex
# all_TEX/2013_1_1.tex
# all_TEX/2012_3_6.tex
# all_TEX/2009_4_6.tex
# all_TEX/2011_2_6.tex
# all_TEX/2008_2_5.tex
# all_TEX/2010_4_5.tex
# all_TEX/2010_4_1.tex
# all_TEX/2005_4_10.tex
# all_TEX/2004_4_10.tex
# all_TEX/2008_2_1.tex
# all_TEX/2009_2_4.tex
# all_TEX/2011_4_4.tex
# all_TEX/2016_1_8.tex
# all_TEX/2014_4_9.tex
# all_TEX/2004_4_9.tex
# all_TEX/2011_2_2.tex
# all_TEX/2009_4_2.tex
# all_TEX/2012_3_2.tex
# all_TEX/2013_1_5.tex
# all_TEX/2008_4_7.tex
# all_TEX/2010_2_7.tex
# all_TEX/2013_3_7.tex
# all_TEX/2013_3_6.tex
# all_TEX/2012_1_1.tex
# all_TEX/2010_2_6.tex
# all_TEX/2008_4_6.tex
# all_TEX/2013_1_4.tex
# all_TEX/2012_3_3.tex
# all_TEX/2009_4_3.tex
# all_TEX/2011_2_3.tex
# all_TEX/2004_4_8.tex
# all_TEX/2014_4_8.tex
# all_TEX/2016_1_9.tex
# all_TEX/2011_4_5.tex
# all_TEX/2009_2_5.tex
# all_TEX/2005_2_9.tex
# all_TEX/2015_2_9.tex
# all_TEX/2008_2_2.tex
# all_TEX/2010_4_2.tex
# all_TEX/2011_4_7.tex
# all_TEX/2009_2_7.tex
# all_TEX/2009_4_1.tex
# all_TEX/2011_2_1.tex
# all_TEX/2013_1_6.tex
# all_TEX/2012_3_1.tex
# all_TEX/2010_2_4.tex
# all_TEX/2008_4_4.tex
# all_TEX/2013_3_4.tex
# all_TEX/2012_1_3.tex
# all_TEX/2012_1_2.tex
# all_TEX/2013_3_5.tex
# all_TEX/2008_4_5.tex
# all_TEX/2013_1_7.tex
# all_TEX/2009_2_6.tex
# all_TEX/2011_4_6.tex
# all_TEX/2010_4_3.tex
# all_TEX/2008_2_3.tex
# all_TEX/2015_2_10.tex
# all_TEX/2015_2_8.tex
# all_TEX/2014_2_10.tex
# all_TEX/2005_2_8.tex
# all_TEX/2015_2_5.tex
# all_TEX/2005_2_5.tex
# all_TEX/2007_1_2.tex
# all_TEX/2006_3_5.tex
# all_TEX/2016_1_7.tex
# all_TEX/2006_1_7.tex
# all_TEX/2014_4_6.tex
# all_TEX/2004_4_6.tex
# all_TEX/2005_4_3.tex
# all_TEX/2015_4_3.tex
# all_TEX/2008_4_8.tex
# all_TEX/2013_3_10.tex
# all_TEX/2010_2_8.tex
# all_TEX/2013_3_8.tex
# all_TEX/2013_3_9.tex
# all_TEX/2010_2_9.tex
# all_TEX/2013_3_11.tex
# all_TEX/2015_4_2.tex
# all_TEX/2005_4_2.tex
# all_TEX/2004_4_7.tex
# all_TEX/2014_4_7.tex
# all_TEX/2006_1_6.tex
# all_TEX/2016_1_6.tex
# all_TEX/2007_3_1.tex
# all_TEX/2014_2_1.tex
# all_TEX/2004_2_1.tex
# all_TEX/2006_3_4.tex
# all_TEX/2007_1_3.tex
# all_TEX/2005_2_4.tex
# all_TEX/2015_2_4.tex
# all_TEX/2005_2_6.tex
# all_TEX/2015_2_6.tex
# all_TEX/2007_1_1.tex
# all_TEX/2014_2_3.tex
# all_TEX/2004_2_3.tex
# all_TEX/2011_4_8.tex
# all_TEX/2006_1_4.tex
# all_TEX/2007_3_3.tex
# all_TEX/2016_1_4.tex
# all_TEX/2004_4_5.tex
# all_TEX/2014_4_5.tex
# all_TEX/2013_1_9.tex
# all_TEX/2004_1_10.tex
# all_TEX/2013_3_12.tex
# all_TEX/2005_4_1.tex
# all_TEX/2015_4_1.tex
# all_TEX/2013_1_8.tex
# all_TEX/2014_4_4.tex
# all_TEX/2004_4_4.tex
# all_TEX/2007_3_2.tex
# all_TEX/2016_1_5.tex
# all_TEX/2006_1_5.tex
# all_TEX/2004_2_2.tex
# all_TEX/2014_2_2.tex
# all_TEX/2015_2_7.tex
# all_TEX/2005_2_7.tex
# all_TEX/2008_2_8.tex
# all_TEX/2005_3_10.tex
# all_TEX/2010_4_8.tex
# all_TEX/2005_2_3.tex
# all_TEX/2015_2_3.tex
# all_TEX/2006_3_3.tex
# all_TEX/2007_1_4.tex
# all_TEX/2014_2_6.tex
# all_TEX/2004_2_6.tex
# all_TEX/2006_1_1.tex
# all_TEX/2016_1_1.tex
# all_TEX/2007_3_6.tex
# all_TEX/2015_4_5.tex
# all_TEX/2005_4_5.tex
# all_TEX/2012_1_8.tex
# all_TEX/2005_4_4.tex
# all_TEX/2015_4_4.tex
# all_TEX/2014_4_1.tex
# all_TEX/2004_4_1.tex
# all_TEX/2007_3_7.tex
# all_TEX/2004_2_7.tex
# all_TEX/2014_2_7.tex
# all_TEX/2007_1_5.tex
# all_TEX/2006_3_2.tex
# all_TEX/2015_2_2.tex
# all_TEX/2005_2_2.tex
# all_TEX/2013_1_12.tex
# all_TEX/2010_4_9.tex
# all_TEX/2005_3_11.tex
# all_TEX/2013_1_10.tex
# all_TEX/2007_1_7.tex
# all_TEX/2004_2_5.tex
# all_TEX/2014_2_5.tex
# all_TEX/2007_3_5.tex
# all_TEX/2016_1_2.tex
# all_TEX/2006_1_2.tex
# all_TEX/2011_2_8.tex
# all_TEX/2009_4_8.tex
# all_TEX/2014_4_3.tex
# all_TEX/2004_4_3.tex
# all_TEX/2012_3_8.tex
# all_TEX/2005_4_6.tex
# all_TEX/2015_4_6.tex
# all_TEX/2015_4_7.tex
# all_TEX/2005_4_7.tex
# all_TEX/2004_4_2.tex
# all_TEX/2014_4_2.tex
# all_TEX/2011_2_9.tex
# all_TEX/2006_1_3.tex
# all_TEX/2007_3_4.tex
# all_TEX/2016_1_3.tex
# all_TEX/2014_2_4.tex
# all_TEX/2004_2_4.tex
# all_TEX/2006_3_1.tex
# all_TEX/2007_1_6.tex
# all_TEX/2005_2_1.tex
# all_TEX/2015_2_1.tex
# all_TEX/2005_3_12.tex
# all_TEX/2013_1_11.tex
# all_TEX/2007_4_5.tex
# all_TEX/2005_1_4.tex
# all_TEX/2014_3_3.tex
# all_TEX/2015_1_4.tex
# all_TEX/2004_3_3.tex
# all_TEX/2007_2_3.tex
# all_TEX/2012_4_8.tex
# all_TEX/2014_1_1.tex
# all_TEX/2005_3_6.tex
# all_TEX/2004_1_1.tex
# all_TEX/2015_3_6.tex
# all_TEX/2006_2_6.tex
# all_TEX/2016_2_6.tex
# all_TEX/2016_2_7.tex
# all_TEX/2006_2_7.tex
# all_TEX/2015_3_7.tex
# all_TEX/2005_3_7.tex
# all_TEX/2012_4_9.tex
# all_TEX/2007_2_2.tex
# all_TEX/2015_1_5.tex
# all_TEX/2004_3_2.tex
# all_TEX/2005_1_5.tex
# all_TEX/2014_3_2.tex
# all_TEX/2007_4_4.tex
# all_TEX/2006_4_1.tex
# all_TEX/2010_3_8.tex
# all_TEX/2006_4_3.tex
# all_TEX/2013_2_8.tex
# all_TEX/2015_1_10.tex
# all_TEX/2007_4_6.tex
# all_TEX/2015_1_7.tex
# all_TEX/2005_1_7.tex
# all_TEX/2015_3_5.tex
# all_TEX/2004_1_2.tex
# all_TEX/2005_3_5.tex
# all_TEX/2014_1_2.tex
# all_TEX/2016_2_5.tex
# all_TEX/2006_2_5.tex
# all_TEX/2006_2_4.tex
# all_TEX/2016_2_4.tex
# all_TEX/2005_3_4.tex
# all_TEX/2014_1_3.tex
# all_TEX/2015_3_4.tex
# all_TEX/2004_1_3.tex
# all_TEX/2007_2_1.tex
# all_TEX/2014_3_1.tex
# all_TEX/2005_1_6.tex
# all_TEX/2004_3_1.tex
# all_TEX/2015_1_6.tex
# all_TEX/2007_4_7.tex
# all_TEX/2013_2_9.tex
# all_TEX/2006_4_2.tex
# all_TEX/2006_4_6.tex
# all_TEX/2011_3_8.tex
# all_TEX/2012_2_8.tex
# all_TEX/2008_1_10.tex
# all_TEX/2007_4_3.tex
# all_TEX/2008_1_9.tex
# all_TEX/2015_1_2.tex
# all_TEX/2004_3_5.tex
# all_TEX/2005_1_2.tex
# all_TEX/2015_3_10.tex
# all_TEX/2014_3_5.tex
# all_TEX/2007_2_5.tex
# all_TEX/2004_1_7.tex
# all_TEX/2014_1_7.tex
# all_TEX/2006_2_1.tex
# all_TEX/2016_2_1.tex
# all_TEX/2010_4_12.tex
# all_TEX/2014_1_6.tex
# all_TEX/2005_3_1.tex
# all_TEX/2004_1_6.tex
# all_TEX/2015_3_1.tex
# all_TEX/2007_2_4.tex
# all_TEX/2005_1_3.tex
# all_TEX/2014_3_4.tex
# all_TEX/2015_3_11.tex
# all_TEX/2015_1_3.tex
# all_TEX/2004_3_4.tex
# all_TEX/2008_1_8.tex
# all_TEX/2007_4_2.tex
# all_TEX/2008_1_11.tex
# all_TEX/2012_2_9.tex
# all_TEX/2006_4_7.tex
# all_TEX/2011_1_9.tex
# all_TEX/2006_4_5.tex
# all_TEX/2014_3_6.tex
# all_TEX/2005_1_1.tex
# all_TEX/2004_3_6.tex
# all_TEX/2015_1_1.tex
# all_TEX/2007_2_6.tex
# all_TEX/2008_3_8.tex
# all_TEX/2005_3_3.tex
# all_TEX/2014_1_4.tex
# all_TEX/2015_3_3.tex
# all_TEX/2004_1_4.tex
# all_TEX/2010_4_10.tex
# all_TEX/2013_4_8.tex
# all_TEX/2006_2_3.tex
# all_TEX/2016_2_3.tex
# all_TEX/2016_2_2.tex
# all_TEX/2006_2_2.tex
# all_TEX/2013_4_9.tex
# all_TEX/2010_4_11.tex
# all_TEX/2015_3_2.tex
# all_TEX/2004_1_5.tex
# all_TEX/2005_3_2.tex
# all_TEX/2014_1_5.tex
# all_TEX/2007_2_7.tex
# all_TEX/2004_3_7.tex
# all_TEX/2014_3_7.tex
# all_TEX/2007_4_1.tex
# all_TEX/2006_4_4.tex
# all_TEX/2011_1_8.tex

# %%
# Open and clean tex doc
def next_tex_doc(address):
    doc = "" # returning value, string
    texdoc = []  # a list of string representing the latex document in python
    # read the .tex file, and modify the lines
    with open(address, 'UTF-8') as texdoc:
        for line in texdoc:
            l = unicode(line, 'utf-8')
            if l.find('%') != 0:
              #  print l
                if len(l) > 0:
                #    l = l.lower().replace("~---", "")
                    l = l.replace(".~", ". ")
                    l = l.replace("{", ' ').replace("}", ' ')
                    l = l.replace("(", ' ').replace(")", ' ')
                    l = l.replace("[", ' ').replace("]", ' ')
                    l = l.replace("<", ' ').replace(">", ' ')
                    l = l.replace(".", ' ')
                    l = l.replace(",", ' ')
                    l = l.replace("!", ' ')
                    l = l.replace("?", ' ')
                    l = l.replace(";", ' ').replace(":", ' ')
                    doc = doc + l.replace("\n", " ")
    doc = doc + ' '
    return doc

# %%
doc = next_tex_doc('all_TEX/2004_1_1.tex')
print doc
# Out:
#  \def\endpage 1    \thispagestyle empty  \vspace* 30mm  \begin center  \includegraphics width=6 5cm  bukh/abr1 eps  \\ 4pt  Юрий Александрович Абрамович \\  1945--2003  \end center    \newpage\thispagestyle empty  \ \  \makeatletter% @  \renewcommand \@evenhead       \raisebox 0pt  \headheight  0pt %  \vbox \hbox to\textwidth \issu--\thepage \hfill\strut  \sl Памяти Юрия Александровича Абрамовича  \hrule    \makeatother%@  \newpage\beginarticle  \addcontentsline toc  contpart  \protect  Бухвалов А  В   Памяти Юрия Александровича Абрамовича    \Title Памяти Юрия Александровича Абрамовича   \shorttitle Памяти Юрия Александровича Абрамовича        С середины 1960-х до середины 1970-х гг  на математико-механическом факультете Ленинградского государственного университета работал городской семинар по теории полуупорядоченных пространств  который возглавлял Борис Захарович Вулих  заведующий кафедрой математического анализа и ученик Леонида Витальевича Канторовича~--- блестящего математика и экономиста  заложившего основы теории этих пространств в конце 1930-х гг  Участие в этом семинаре осталось как самое яркое воспоминание о совместной работе сплоченной группы людей  преданных своей деятельности  Старшие участники этого семинара  Б  З  Вулих  А  И  Векслер  Д  А  Владимиров  Г  Я  Лозановский  привили многочисленной тогда молодежи идеалы честного служения чистой науке  высокой требовательности к себе и к другим  полной самоотдачи   Юрий Александрович Абрамович  1945--2003   принадлежавший  как и автор этих строк  к младшему поколению участников семинара  реализовал всей своей жизнью принципы преданности избранному разделу науки  заложенные в те годы  Я познакомился с Юрием  когда в 1967/1968 учебном году был слушателем спецкурса по основам теории полуупорядоченных пространств  который впервые читался на матмехе триумвиратом  состоящим из Бориса Захаровича Вулиха  Григория Яковлевича Лозановского и Дениса Артемьевича Владимирова  В следующие годы серию продолжающихся спецкурсов по этой тематике уже читал один Г  Я  Лозановский  Юра был старшим и самым активным слушателем  во многом формировавшим своим спросом уровень чтения спецкурса   Личность и талант Григория Яковлевича оказали наибольшее влияние на формирование интересов и у Юры и у меня  Теория полуупорядоченных пространств принадлежит одновременно алгебре  с ответвлениями в математическую логику и теоретико-множественную топологию  и функциональному анализу  Так получилось  что до середины 1960-х гг  основные исследования ленинградской школы касались в основном первого направления  Это же направление стало важнейшим и для сформировавшейся позднее стараниями Глеба Павловича Акилова новосибирской школы  Новаторская роль Григория Яковлевича заключалась в том  что он поставил и сам активно реализовывал задачу синтеза теории векторных решеток с теорией банаховых пространств и операторов в них  Одновременно он осуществлял синтез абстрактной теории банаховых решеток с теорией банаховых пространств измеримых функций  Здесь он находился под влиянием пионерной серии статей нидерландских математиков В  Люксембурга и А  Заанена  содержание которых он пересказывал в спецкурсе  как только выпуски математического журнала Нидерландской академии наук попадали в БАН  Однако в своих результатах он пошел много дальше  что было связано с тем  что он преследовал не просто абстрактные цели построения замкнутой теории  а видел многочисленные приложения за рамками полуупорядоченных пространств  Третьей составляющей его занятий была теория интерполяционных пространств  где он отталкивался от классической работы А  Кальдерона по комплексному методу интерполяции и собственных результатов  полученных в рамках второго из упомянутых синтезов  Это была потрясающая перспектива будущей деятельности  в которую мы с Юрой сразу влюбились  На меня также подействовали результаты Д  А  Владимирова и Г  Я  Лозановского по интегральным операторам   Формально Григорий Яковлевич не был руководителем ни у Юры  ни у меня   ...

# %%
norm_lst = []
norm_lst_num = []
num = 0
lst = doc.encode('utf-8').split()
for word in lst:
    w = morph.parse(word.decode('utf-8'))[0]
    norm_lst.append(w.normal_form)
    norm_lst_num.append(num)
    num = num + len(w.normal_form) + 1
norm_doc = " ".join(norm_lst)
print norm_doc
print "____________"
print norm_lst_num
print norm_doc[13:15]
print norm_doc[15:30]
# Out:
# \def\endpage 1 \thispagestyle empty \vspace* 30mm \begin center \includegraphics width=6 5cm bukh/abr1 eps \\ 4pt юрий александрович абрамович \\ 1945--2003 \end center \newpage\thispagestyle empty \ \ \makeatletter% @ \renewcommand \@evenhead \raisebox 0pt \headheight 0pt % \vbox \hbox to\textwidth \issu--\thepage \hfill\strut \sl память юрий александрович абрамович \hrule \makeatother%@ \newpage\beginarticle \addcontentsline toc contpart \protect бухвалов а в память юрий александрович абрамович \title память юрий александрович абрамович \shorttitle память юрий александрович абрамович с середина 1960-й до середина 1970-й год на математико-механический факультет ленинградский государственный университет работать городской семинар по теория полуупорядочить пространство который возглавлять борис захарович вулихо заведовать кафедра математический анализ и ученик леонид виталиевич канторовича~--- блестящий математик и экономист заложить основа теория этот пространство в конец 1930-й год участие в это семинар остаться как самый яркий воспоминание о совместный работа сплотить группа человек предать свой деятельность старший участник это семинар б з вулихо а и векслер далее а владимир г я лозановский привить многочисленный тогда молодёжь идеал честной служение чистый наука высокий требовательность к себя и к другой полный самоотдача юрий александрович абрамович 1945--2003 принадлежать как и автор этот строка к младший поколение участник семинар реализовать весь свой жизнь принцип преданность избранный раздел наука заложить в тот год я познакомиться с юрий когда в 1967/1968 учебный год быть слушатель спецкурс по основа теория полуупорядочить пространство который впервые читаться на матмех триумвират состоять из борис захарович вулихо григорий яковлевич лозановский и денис артемиевич владимиров в следующий год серия продолжаться спецкурс по этот тематика уже читать один г я лозановский юра быть старший и самый активный слушатель в многое формировать свой спрос уровень чтение спецкурс личность и талант григорий яковлевич оказать больший влияние на формирование интерес и у юр и у я теория полуупорядочить пространство принадлежать одновременно алгебра с ответвление в математический логика и теоретико-множественный топология и функциональный анализ так получиться что до середина 1960-й год основной исследование ленинградский школа касаться в основное первый направление это же направление стать важный и для сформироваться поздний старание глеб павлович акиловый новосибирский школа новаторский роль григорий яковлевич заключаться в тот что он поставить и сам активно реализовывать задача синтез теория векторный решётка с теория банахов пространство и оператор в они одновременно он осуществлять синтез абстрактный теория банахов решётка с теория банахов пространство измеримый функция здесь он находиться под влияние пионерный серия стать нидерландский математик в люксембург и а заанена содержание который он пересказывать в спецкурс как только выпуск математический журнал нидерландский академия наука попадать в бан однако в свой результат он пойти много далёкий что быть связать с тем что он преследовать не просто абстрактный цель построение замкнутый теория а видеть многочисленный приложение за рамка полуупорядочить пространство третий составлять он занятие быть теория интерполяционный пространство где он отталкиваться от классический работа а кальдерон по комплексный метод интерполяция и собственный результат получить в рамка второй из упомянуть синтез это быть потрясать перспектива будущий деятельность в который мы с юра сразу влюбиться на я также подействовать результат далее а владимиров и г я лозановский по интегральный оператор формально григорий яковлевич не быть руководитель ни у юр ни у я к сожаление он работать в университет только совместитель аспирантура мы оба кончать у б з вулихо в общение борис захарович быть холодноватый от что как выясниться поздний страдать сам но он быть для мы образец честность и чистоплотность в наука активно  ...
# ____________
# [0, 13, 15, 30, 36, 45, 50, 57, 64, 81, 89, 93, 103, 107, 110, 114, 119, 133, 143, 146, 157, 162, 169, 192, 198, 200, 202, 217, 219, 233, 244, 254, 258, 270, 274, 276, 282, 288, 301, 317, 330, 334, 341, 346, 360, 370, 377, 392, 414, 431, 435, 444, 453, 462, 464, 466, 473, 478, 492, 502, 509, 516, 521, 535, 545, 557, 564, 569, 583, 593, 595, 604, 611, 614, 623, 630, 634, 637, 661, 671, 685, 701, 713, 722, 732, 740, 743, 750, 766, 779, 787, 799, 805, 815, 822, 833, 841, 856, 863, 865, 872, 879, 890, 906, 916, 926, 928, 938, 947, 954, 961, 966, 979, 981, 987, 994, 998, 1006, 1008, 1012, 1020, 1029, 1033, 1039, 1045, 1058, 1060, 1071, 1078, 1087, 1094, 1102, 1110, 1115, 1128, 1136, 1145, 1149, 1157, 1159, 1161, 1168, 1170, 1172, 1180, 1186, 1188, 1197, 1199, 1201, 1213, 1221, 1236, 1242, 1251, 1257, 1265, 1274, 1281, 1287, 1295, 1312, 1314, 1319, 1321, 1323, 1330, 1337, 1348, 1353, 1367, 1377, 1388, 1401, 1405, 1407, 1413, 1418, 1425, 1427, 1435, 1445, 1454, 1462, 1474, 1479, 1484, 1490, 1498, 1510, 1520, 1527, 1533, 1542, 1544, 1548, 1552, 1554, 1568, 1570, 1575, 1581, 1583, 1593, 1601, 1605, 1610, 1620, 1629, 1632, 1639, 1646, 1662, 1675, 1683, 1691, 1700, 1703, 1710, 1721, 1730, 1733, 1739, 1749, 1756, 1765, 1775, 1787, 1789, 1795, 1806, 1817, 1819, 1829, 1833, 1839, 1852, 1861, 1864, 1869, 1878, 1882, 1889, 1894, 1896, 1898, 1910, 1914, 1919, 1927, 1929, 1935, 1944, 1954, 1956, 1963, 1975, 1980, 1986, 1994, 2001, 2010, 2019, 2021, 2028, 2037, 2047, 2055, 2063, 2071, 2074, 2087, 2095, 2097, 2099, 2102, 2104, 2106, 2108, 2115, 2131, 2144, 2157, 2170, 2178, 2180, 2192, 2194, 2209, 2216, 2218, 2242, 2252, 2254, 2269, 2276, 2280, 2291, 2295, 2298, 2307, 2314, 2318, 2327, 2340, 2354, 2360, 2369, 2371, 2380, 2387, 2399, 2403, 2406, 2418, 2424, 2431, 2433, 2437, 2452, 2460, 2469, 2474, 2483, 2492, 2506, 2512, 2524, 2529, 2538, 2548, 2560, 2562, 2566, 2570, 2573, 2583, 2585, 2589, 2597, 2611, 2618, 2625, 2632, 2642, 2650, 2652, 2659, 2667, 2680, 2682, 2691, 2693, 2697, 2710, 2713, 2726, 2733, 2745, 2752, 2760, 2768, 2770, 2777, 2785, 2798, 2808, 2816, 2822, 2825, 2836, 2840, 2848, 2858, 2864, 2870, 2884, 2894, 2896, 2907, 2909, 2911, 2919, 2930, 2938, 2941, 2955, 2957, 2966, 2970, 2977, 2984, 2999, 3006, 3020, 3029, 3035, 3044, 3046, 3050, 3057, 3059, 3064, 3074, 3077, 3083, 3089, 3097, 3101, 3106, 3114, 3116, 3120, 3124, 3127, 3140, 3143, 3150, 3162, 3167, 3178, 3188, 3195, 3197, 3204, 3219, 3230, 3233, 3239, 3255, 3268, 3275, 3286, 3289, 3297, 3302, 3309, 3326, 3339, 3343, 3346, 3360, 3363, 3376, 3383, 3385, 3395, 3398, 3410, 3416, 3429, 3431, 3443, 3453, 3462, 3464, 3470, 3477, 3480, 3490, 3497, 3501, 3506, 3516, 3528, 3536, 3549, 3551, 3559, 3562, 3564, 3568, 3574, 3584, 3587, 3589, 3595, 3609, 3619, 3625, 3627, 3638, 3640, 3642, 3644, 3656, 3659, 3672, 3681, 3691, 3700, 3710, 3713, 3718, 3731, 3734, 3736, 3739, 3742, 3744, 3746, 3748, 3758, 3761, 3770, 3772, 3784, 3791, 3804, 3816, 3819, 3823, 3831, 3833, 3835, 3837, 3844, 3846, 3854, 3860, 3870, 3875, 3888, 3891, 3895, 3899, 3910, 3918, 3927, 3931, 3934, 3937, 3942, 3946, 3949, 3957, 3967, 3969, 3984, 3986, 3992, 4000, 4003, 4010, 4019, 4021, 4025, 4031, 4036, 4038, 4040, 4046, 4054, 4064, 4069, 4071, 4075, 4080, 4084, 4093, 4095, 4104, 4109, 4116, 4126, 4128, 4135, 4138, 4149, 4158, 4168, 4170, 4179, 4188, 4197, 4207, 4219, 4230, 4233, 4242, 4251, 4261, 4269, 4276, 4284, 4286, 4294, 4297, 4302, 4305, 4317, 4327, 4337, 4342, 4352, 4357, 4363, 4374, 4377, 4387, 4389, 4395, 4397, 4401, 4403, 4411, 4420, 4422, 4425, 4429, 4431, 4439, 4445, 4458, 4465, 4469, 4475, 4485, 4494, 4499, 4509, 4512, 4518, 4525, 4532, 4536, 4546, 4554, 4557, 4562, 4565, 4572, 4576, 4582, 4592, 4600, 4602, 4606, 4611, 4613, 4619, 4626, 4628, 4631, 4635, 4638, 4643, 4648, 4656, 4678, 4684, 4686, 4706, 4714, 4716, 4721, 4727, 4735, 4737, 4740, 4744, 4749, 4755, 4766, 4769, 4773, 4792, 4797, 4800, 4810, 4815, 4817, 4822, 4825, 4834, 4836, 4841, 4843, 4855, 4857, 4862, 4871, 4879, 4884, 4886, 4893, 4901, 4904, 4 ...
# 1
# \thispagestyle

# %%
num = 0
lst_num = []
for item in lst:
    num = num + doc[num:].find(item.decode('utf-8'))
    lst_num.append(num)
print lst_num
print doc[1:14]
print doc[14:19]
# Out:
# [1, 14, 19, 34, 41, 50, 56, 63, 71, 88, 96, 101, 111, 116, 119, 124, 129, 143, 153, 157, 169, 174, 184, 207, 214, 214, 219, 234, 237, 251, 268, 278, 283, 296, 300, 303, 309, 315, 328, 344, 358, 362, 369, 374, 389, 401, 411, 427, 450, 467, 472, 482, 492, 501, 504, 508, 515, 520, 535, 549, 556, 563, 568, 583, 596, 608, 615, 620, 635, 653, 655, 664, 671, 674, 683, 690, 694, 697, 721, 732, 747, 764, 777, 785, 795, 803, 806, 813, 831, 844, 852, 863, 869, 879, 886, 897, 906, 922, 926, 932, 939, 947, 959, 975, 986, 993, 999, 1011, 1023, 1030, 1037, 1042, 1052, 1056, 1062, 1069, 1073, 1081, 1083, 1088, 1097, 1106, 1110, 1116, 1122, 1123, 1137, 1148, 1155, 1166, 1173, 1180, 1190, 1196, 1210, 1218, 1228, 1234, 1244, 1247, 1250, 1257, 1260, 1263, 1272, 1275, 1278, 1290, 1293, 1296, 1309, 1317, 1332, 1338, 1347, 1354, 1363, 1372, 1379, 1386, 1394, 1411, 1413, 1418, 1420, 1422, 1430, 1437, 1450, 1455, 1469, 1480, 1493, 1509, 1513, 1515, 1521, 1526, 1530, 1535, 1544, 1554, 1565, 1575, 1586, 1591, 1597, 1604, 1613, 1625, 1636, 1644, 1651, 1662, 1664, 1667, 1673, 1675, 1685, 1690, 1697, 1703, 1705, 1715, 1723, 1728, 1732, 1743, 1753, 1756, 1764, 1771, 1789, 1802, 1810, 1818, 1826, 1829, 1837, 1851, 1861, 1864, 1871, 1882, 1890, 1899, 1910, 1923, 1925, 1932, 1944, 1944, 1959, 1969, 1974, 1980, 1995, 2006, 2009, 2014, 2023, 2027, 2033, 2038, 2041, 2044, 2057, 2061, 2065, 2070, 2075, 2081, 2090, 2102, 2105, 2112, 2126, 2132, 2140, 2148, 2155, 2167, 2168, 2178, 2185, 2194, 2205, 2213, 2224, 2232, 2235, 2248, 2248, 2260, 2262, 2266, 2268, 2270, 2276, 2283, 2301, 2313, 2325, 2338, 2347, 2349, 2351, 2365, 2380, 2383, 2389, 2413, 2420, 2426, 2442, 2451, 2455, 2467, 2471, 2474, 2483, 2490, 2494, 2503, 2516, 2530, 2536, 2545, 2547, 2556, 2564, 2577, 2581, 2584, 2596, 2602, 2609, 2614, 2618, 2635, 2643, 2654, 2660, 2670, 2678, 2692, 2699, 2711, 2716, 2725, 2736, 2748, 2750, 2755, 2759, 2762, 2768, 2773, 2777, 2785, 2798, 2805, 2813, 2820, 2830, 2838, 2840, 2848, 2858, 2870, 2872, 2881, 2885, 2890, 2903, 2906, 2918, 2925, 2937, 2944, 2954, 2962, 2964, 2972, 2982, 2994, 3004, 3013, 3019, 3022, 3032, 3036, 3045, 3055, 3061, 3068, 3082, 3094, 3097, 3109, 3111, 3114, 3123, 3134, 3142, 3145, 3154, 3160, 3171, 3175, 3182, 3190, 3206, 3214, 3228, 3237, 3242, 3251, 3253, 3258, 3265, 3267, 3273, 3285, 3288, 3294, 3300, 3308, 3312, 3317, 3317, 3327, 3332, 3336, 3339, 3351, 3354, 3361, 3373, 3378, 3389, 3399, 3407, 3409, 3415, 3430, 3441, 3444, 3452, 3470, 3483, 3491, 3504, 3508, 3516, 3521, 3528, 3545, 3558, 3562, 3565, 3565, 3581, 3594, 3601, 3604, 3615, 3618, 3631, 3638, 3638, 3653, 3665, 3678, 3689, 3691, 3698, 3706, 3709, 3720, 3730, 3734, 3739, 3751, 3763, 3771, 3785, 3787, 3795, 3798, 3800, 3805, 3811, 3822, 3825, 3830, 3836, 3850, 3861, 3864, 3867, 3871, 3881, 3884, 3887, 3900, 3903, 3916, 3929, 3939, 3948, 3958, 3961, 3965, 3979, 3982, 3984, 3989, 3992, 3994, 4000, 4002, 4013, 4016, 4024, 4026, 4039, 4046, 4062, 4074, 4077, 4081, 4089, 4091, 4094, 4097, 4097, 4107, 4115, 4121, 4131, 4135, 4147, 4150, 4156, 4160, 4171, 4178, 4186, 4192, 4195, 4198, 4202, 4206, 4210, 4219, 4227, 4231, 4246, 4248, 4255, 4263, 4266, 4273, 4279, 4284, 4289, 4296, 4301, 4304, 4306, 4312, 4319, 4329, 4335, 4337, 4341, 4345, 4349, 4361, 4363, 4371, 4376, 4383, 4394, 4396, 4402, 4406, 4417, 4427, 4430, 4441, 4450, 4459, 4468, 4478, 4490, 4501, 4504, 4515, 4524, 4534, 4543, 4551, 4559, 4561, 4568, 4571, 4577, 4580, 4592, 4604, 4614, 4619, 4631, 4636, 4642, 4656, 4659, 4670, 4672, 4672, 4680, 4685, 4687, 4695, 4703, 4705, 4709, 4714, 4716, 4724, 4730, 4744, 4753, 4757, 4763, 4773, 4781, 4786, 4796, 4799, 4808, 4817, 4824, 4829, 4842, 4851, 4854, 4859, 4862, 4869, 4874, 4881, 4893, 4902, 4904, 4908, 4912, 4914, 4920, 4926, 4928, 4932, 4938, 4942, 4947, 4951, 4959, 4985, 4987, 4995, 5015, 5018, 5026, 5032, 5038, 5047, 5049, 5052, 5056, 5060, 5066, 5076, 5079, 5082, 5102, 5108, 5111, 5121, 5126, 5128, 5134, 5137, 5146, 5148, 5152, 5154, 5167, 5169, 5175, 5184, 5192, 5197, 5199, 5207, 52 ...
# \def\endpage
# 1

# %%
x = 0
for item in norm_library:
    num = norm_doc.find(' ' + item + ' ')
    if num > -1:
        print item
        print num
        a = norm_lst_num.index(num + 1)
        print lst_num[a]
        #print a
        nwords = item.count(" ") + 1
        i = 0
        while nwords > 0:
            print lst[a + i]
            nwords = nwords - 1
            i = i + 1
        #print norm_lst[a]
        print "___________________"
        x = x + 1
print x
print doc.find('предложение'.decode('utf-8'))
# Out:
# функциональный анализ
# 2253
# 2426
# функциональному
# анализу
# ___________________
# математический анализ
# 840
# 906
# математического
# анализа
# ___________________
# интегральный оператор
# 3658
# 3903
# интегральным
# операторам
# ___________________
# нестандартный анализ
# 12818
# 13569
# нестандартного
# анализа
# ___________________
# область
# 6758
# 7202
# области
# ___________________
# доказательство
# 11408
# 12089
# доказательство
# ___________________
# группа
# 1086
# 1166
# группы
# ___________________
# период
# 8227
# 8727
# период
# ___________________
# оператор
# 2681
# 2872
# операторов
# ___________________
# решётка
# 2641
# 2830
# решеток
# ___________________
# последовательность
# 6371
# 6787
# последовательностей
# ___________________
# ряд
# 7155
# 7616
# ряду
# ___________________
# теория
# 742
# 806
# теории
# ___________________
# уравнение
# 7293
# 7760
# уравнений
# ___________________
# функция
# 2807
# 3004
# функций
# ___________________
# пространство
# 765
# 831
# пространств
# ___________________
# линия
# 4971
# 5288
# линии
# ___________________
# мера
# 6173
# 6580
# мере
# ___________________
# направление
# 2386
# 2564
# направления
# ___________________
# идеал
# 1250
# 1347
# идеалы
# ___________________
# форма
# 15036
# 15938
# форма
# ___________________
# момент
# 9252
# 9817
# момент
# ___________________
# алгебра
# 2169
# 2338
# алгебре
# ___________________
# масса
# 9574
# 10161
# массу
# ___________________
# интервал
# 4232
# 4504
# интервалах
# ___________________
# норма
# 10389
# 11010
# норме
# ___________________
# перспектива
# 3515
# 3751
# перспектива
# ___________________
# топология
# 2241
# 2413
# топологию
# ___________________
# сходимость
# 4218
# 4490
# сходимости
# ___________________
# математик
# 915
# 986
# математика
# ___________________
# имя
# 7476
# 7950
# именем
# ___________________
# распределение
# 5653
# 6023
# распределением
# ___________________
# машина
# 12216
# 12935
# машины
# ___________________
# разность
# 6424
# 6847
# разности
# ___________________
# решение
# 7663
# 8149
# решение
# ___________________
# интерполяция
# 3415
# 3638
# интерполяции
# ___________________
# проектор
# 10395
# 11016
# проектора
# ___________________
# предложение
# 8696
# 9216
# предложение
# ___________________
# 38
# 9216

# %%
x = 0
for item in norm_library:
    num = norm_doc.find(item[0] + ' ')
    if num > -1:
        if norm_doc.find(' ' + item[0] + ' ') <= -1:
            print item[0]
            print num
            print "___________________"
        x = x + 1
x
# Out:
# отношение
# 5437
# ___________________
# нить
# 300
# ___________________
# плоскость
# 7943
# ___________________
# деление
# 3207
# ___________________
# сеть
# 7815
# ___________________
# 36

# %%
norm_library = []
library = [] # dictionary of keywords
libmeta = []  # a list of string representing the latex document in python
x = 0

with open('libmeta.txt', 'UTF-8') as libmeta:
    line_type = 0
    for line in libmeta:
        print line
        if line_type == 1:
            line_type = 2 # this string contain link with 'show'
            link_show = line[10:]
        if (line.find("<lbm:Concept rdf:about") == 0) and (line[-2] == '>'):
            line_type = 1 # this string contain term
            y = line.find("#")
            keyword = unicode(line[y+1:-3], 'utf-8')
            x = x + 1
            if len(keyword) > 0:
                item = keyword.replace("_", " ").replace(" - ", "-").lower()
                library.append(item)
                nitem = morph.parse(item)[0]
                norm_library.append(nitem.normal_form)
                if item.count(" ") == 1:
                    d = item.find(" ")
                    library.append(item[d+1:] + ' ' + item[:d])
x
# Out:
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:lbm="http://libmeta.ru/" xmlns:core="http://libmeta.ru/core">
#
# <lbm:Thesaurus rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia">
#
# <lbm:ConceptGroup rdf:about="http://libmeta.ru/thesaurus/group/math_enc_main_cat"> </lbm:ConceptGroup>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Частная_производная">
#
# <core:url>http://libmeta.ru/concept/show/523</core:url>
#
# <core:url>http://libmeta.ru/concept/523</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Логарифмическая_точка_ветвления">
#
# <core:url>http://libmeta.ru/concept/show/513</core:url>
#
# <core:url>http://libmeta.ru/concept/513</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Абсолютно_сходящийся_несобственный_интеграл">
#
# <core:url>http://libmeta.ru/concept/show/527</core:url>
#
# <core:url>http://libmeta.ru/concept/527</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Лобачевского_признак">
#
# <core:url>http://libmeta.ru/concept/show/578</core:url>
#
# <core:url>http://libmeta.ru/concept/578</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Равномерная_сходимость">
#
# <core:url>http://libmeta.ru/concept/show/582</core:url>
#
# <core:url>http://libmeta.ru/concept/582</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Существенное_отображение">
#
# <core:url>http://libmeta.ru/concept/show/617</core:url>
#
# <core:url>http://libmeta.ru/concept/617</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Операторно_неприводимое_представление">
#
# <core:url>http://libmeta.ru/concept/show/726</core:url>
#
# <core:url>http://libmeta.ru/concept/726</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Аддитивная_проблема_делителей">
#
# <core:url>http://libmeta.ru/concept/show/770</core:url>
#
# <core:url>http://libmeta.ru/concept/770</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Конечных_приращений_формула">
#
# <core:url>http://libmeta.ru/concept/show/810</core:url>
#
# <core:url>http://libmeta.ru/concept/810</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Действительная_функция">
#
# <core:url>http://libmeta.ru/concept/show/819</core:url>
#
# <core:url>http://libmeta.ru/concept/819</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Артинов_модуль">
#
# <core:url>http://libmeta.ru/concept/show/643</core:url>
#
# <core:url>http://libmeta.ru/concept/643</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Антитонное_отображение">
#
# <core:url>http://libmeta.ru/concept/show/482</core:url>
#
# <core:url>http://libmeta.ru/concept/482</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Келдыша_теорема">
#
# <core:url>http://libmeta.ru/concept/show/462</core:url>
#
# <core:url>http://libmeta.ru/concept/462</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Наилучших_приближений_последовательность">
#
# <core:url>http://libmeta.ru/concept/show/1078</core:url>
#
# <core:url>http://libmeta.ru/concept/1078</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Вполне_нормальное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/1113</core:url>
#
# <core:url>http://libmeta.ru/concept/1113</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Приближение_в_среднем">
#
# <core:url>http://libmeta.ru/concept/show/760</core:url>
#
# <core:url>http://libmeta.ru/concept/760</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Нульмерное_отображение">
#
# <core:url>http://libmeta.ru/concept/show/660</core:url>
#
# <core:url>http://libmeta.ru/concept/660</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Область">
#
# <core:url>http://libmeta.ru/concept/show/451</core:url>
#
# <core:url>http://libmeta.ru/concept/451</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Дисперсное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/833</core:url>
#
# <core:url>http://libmeta.ru/concept/833</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Вейля_область">
#
# <core:url>http://libmeta.ru/concept/show/475</core:url>
#
# <core:url>http://libmeta.ru/concept/475</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Совершенное_множество">
#
# <core:url>http://libmeta.ru/concept/show/872</core:url>
#
# <core:url>http://libmeta.ru/concept/872</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Счетнокомпактное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/890</core:url>
#
# <core:url>http://libmeta.ru/concept/890</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Финслерово_пространство_обобщенное">
#
# <core:url>http://libmeta.ru/concept/show/922</core:url>
#
# <core:url>http://libmeta.ru/concept/922</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Субдифференциал">
#
# <core:url>http://libmeta.ru/concept/show/940</core:url>
#
# <core:url>http://libmeta.ru/concept/940</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Смешанная_и_краевая_задачи_для_гиперболических_уравнений_и_систем">
#
# <core:url>http://libmeta.ru/concept/show/958</core:url>
#
# <core:url>http://libmeta.ru/concept/958</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Бесселя_интерполяционная_формула">
#
# <core:url>http://libmeta.ru/concept/show/1017</core:url>
#
# <core:url>http://libmeta.ru/concept/1017</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Декартов_лист">
#
# <core:url>http://libmeta.ru/concept/show/1055</core:url>
#
# <core:url>http://libmeta.ru/concept/1055</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Ньютона_-_лейбница_формула">
#
# <core:url>http://libmeta.ru/concept/show/532</core:url>
#
# <core:url>http://libmeta.ru/concept/532</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Односвязная_область">
#
# <core:url>http://libmeta.ru/concept/show/453</core:url>
#
# <core:url>http://libmeta.ru/concept/453</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Распределения_закон">
#
# <core:url>http://libmeta.ru/concept/show/484</core:url>
#
# <core:url>http://libmeta.ru/concept/484</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Римана_дифференциальное_уравнение">
#
# <core:url>http://libmeta.ru/concept/show/499</core:url>
#
# <core:url>http://libmeta.ru/concept/499</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Конформно-евклидово_пространство">
#
# <core:url>http://libmeta.ru/concept/show/557</core:url>
#
# <core:url>http://libmeta.ru/concept/557</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Равномерно_сходящийся_ряд">
#
# <core:url>http://libmeta.ru/concept/show/581</core:url>
#
# <core:url>http://libmeta.ru/concept/581</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Харди_-_литлвуда_теорема">
#
# <core:url>http://libmeta.ru/concept/show/586</core:url>
#
# <core:url>http://libmeta.ru/concept/586</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Арифметический_треугольник">
#
# <core:url>http://libmeta.ru/concept/show/608</core:url>
#
# <core:url>http://libmeta.ru/concept/608</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Неприводимое_отображение">
#
# <core:url>http://libmeta.ru/concept/show/661</core:url>
#
# <core:url>http://libmeta.ru/concept/661</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Сопряженное_линейное_преобразование">
#
# <core:url>http://libmeta.ru/concept/show/702</core:url>
#
# <core:url>http://libmeta.ru/concept/702</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Невырожденное_представление">
#
# <core:url>http://libmeta.ru/concept/show/732</core:url>
#
# <core:url>http://libmeta.ru/concept/732</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гармонический_анализ_абстрактный">
#
# <core:url>http://libmeta.ru/concept/show/749</core:url>
#
# <core:url>http://libmeta.ru/concept/749</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Квазиэквивалентньщ_представления">
#
# <core:url>http://libmeta.ru/concept/show/795</core:url>
#
# <core:url>http://libmeta.ru/concept/795</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Нормальная_производная">
#
# <core:url>http://libmeta.ru/concept/show/818</core:url>
#
# <core:url>http://libmeta.ru/concept/818</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Антидискретное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/835</core:url>
#
# <core:url>http://libmeta.ru/concept/835</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Антидискретная_топология">
#
# <core:url>http://libmeta.ru/concept/show/836</core:url>
#
# <core:url>http://libmeta.ru/concept/836</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Алгебраический_многочлен_наилучшего_приближения">
#
# <core:url>http://libmeta.ru/concept/show/1079</core:url>
#
# <core:url>http://libmeta.ru/concept/1079</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Округления_точка">
#
# <core:url>http://libmeta.ru/concept/show/4089</core:url>
#
# <core:url>http://libmeta.ru/concept/4089</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Относительная_топология">
#
# <core:url>http://libmeta.ru/concept/show/4090</core:url>
#
# <core:url>http://libmeta.ru/concept/4090</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Строгая_эргодичность">
#
# <core:url>http://libmeta.ru/concept/show/541</core:url>
#
# <core:url>http://libmeta.ru/concept/541</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Транспонированная_матрица">
#
# <core:url>http://libmeta.ru/concept/show/682</core:url>
#
# <core:url>http://libmeta.ru/concept/682</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Упорядоченная_полугруппа">
#
# <core:url>http://libmeta.ru/concept/show/1482</core:url>
#
# <core:url>http://libmeta.ru/concept/1482</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Безиковича_почти_периодические_функции">
#
# <core:url>http://libmeta.ru/concept/show/1525</core:url>
#
# <core:url>http://libmeta.ru/concept/1525</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Алгебраических_систем_многообразие">
#
# <core:url>http://libmeta.ru/concept/show/1548</core:url>
#
# <core:url>http://libmeta.ru/concept/1548</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Максиминныи_критерий">
#
# <core:url>http://libmeta.ru/concept/show/1568</core:url>
#
# <core:url>http://libmeta.ru/concept/1568</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Максимальный_идеал">
#
# <core:url>http://libmeta.ru/concept/show/1587</core:url>
#
# <core:url>http://libmeta.ru/concept/1587</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Код_с_исправлением_арифметических_ошибок">
#
# <core:url>http://libmeta.ru/concept/show/1614</core:url>
#
# <core:url>http://libmeta.ru/concept/1614</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Нагруженное_интегральное_уравнение">
#
# <core:url>http://libmeta.ru/concept/show/1640</core:url>
#
# <core:url>http://libmeta.ru/concept/1640</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гомологическая_последовательность">
#
# <core:url>http://libmeta.ru/concept/show/1678</core:url>
#
# <core:url>http://libmeta.ru/concept/1678</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Галуа_топологическая_группа">
#
# <core:url>http://libmeta.ru/concept/show/1717</core:url>
#
# <core:url>http://libmeta.ru/concept/1717</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Трубчатая_область">
#
# <core:url>http://libmeta.ru/concept/show/474</core:url>
#
# <core:url>http://libmeta.ru/concept/474</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Самоинъективное_кольцо">
#
# <core:url>http://libmeta.ru/concept/show/1699</core:url>
#
# <core:url>http://libmeta.ru/concept/1699</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Строфоида">
#
# <core:url>http://libmeta.ru/concept/show/1054</core:url>
#
# <core:url>http://libmeta.ru/concept/1054</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Сопряженный_оператор">
#
# <core:url>http://libmeta.ru/concept/show/881</core:url>
#
# <core:url>http://libmeta.ru/concept/881</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Постоянной_кривизны_пространство">
#
# <core:url>http://libmeta.ru/concept/show/1504</core:url>
#
# <core:url>http://libmeta.ru/concept/1504</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Полинильпотентная_группа">
#
# <core:url>http://libmeta.ru/concept/show/1149</core:url>
#
# <core:url>http://libmeta.ru/concept/1149</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Меньшова_-_радемахера_теорема">
#
# <core:url>http://libmeta.ru/concept/show/627</core:url>
#
# <core:url>http://libmeta.ru/concept/627</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Ортогональное_преобразование">
#
# <core:url>http://libmeta.ru/concept/show/700</core:url>
#
# <core:url>http://libmeta.ru/concept/700</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гольдбаха_-_варинга_проблема">
#
# <core:url>http://libmeta.ru/concept/show/776</core:url>
#
# <core:url>http://libmeta.ru/concept/776</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Выпуклых_множеств_пространство">
#
# <core:url>http://libmeta.ru/concept/show/711</core:url>
#
# <core:url>http://libmeta.ru/concept/711</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Направленное_множество">
#
# <core:url>http://libmeta.ru/concept/show/898</core:url>
#
# <core:url>http://libmeta.ru/concept/898</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Алгебраически_замкнутое_поле">
#
# <core:url>http://libmeta.ru/concept/show/916</core:url>
#
# <core:url>http://libmeta.ru/concept/916</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Достаточное_множество_функционалов">
#
# <core:url>http://libmeta.ru/concept/show/938</core:url>
#
# <core:url>http://libmeta.ru/concept/938</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Вторая_краевая_задача">
#
# <core:url>http://libmeta.ru/concept/show/956</core:url>
#
# <core:url>http://libmeta.ru/concept/956</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Самосопряженное_дифференциальное_уравнение">
#
# <core:url>http://libmeta.ru/concept/show/986</core:url>
#
# <core:url>http://libmeta.ru/concept/986</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Случайный_процесс_со_стационарными_приращениями">
#
# <core:url>http://libmeta.ru/concept/show/1025</core:url>
#
# <core:url>http://libmeta.ru/concept/1025</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Скользящего_среднего_процесс">
#
# <core:url>http://libmeta.ru/concept/show/1026</core:url>
#
# <core:url>http://libmeta.ru/concept/1026</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Аполярные_сети">
#
# <core:url>http://libmeta.ru/concept/show/1051</core:url>
#
# <core:url>http://libmeta.ru/concept/1051</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Жордана_разложение">
#
# <core:url>http://libmeta.ru/concept/show/1088</core:url>
#
# <core:url>http://libmeta.ru/concept/1088</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Относительно_бикомпактное_множество">
#
# <core:url>http://libmeta.ru/concept/show/1104</core:url>
#
# <core:url>http://libmeta.ru/concept/1104</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Локально_разрешимая_алгебра">
#
# <core:url>http://libmeta.ru/concept/show/1120</core:url>
#
# <core:url>http://libmeta.ru/concept/1120</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Симплициальное_множество">
#
# <core:url>http://libmeta.ru/concept/show/1164</core:url>
#
# <core:url>http://libmeta.ru/concept/1164</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гильберта_система_аксиом">
#
# <core:url>http://libmeta.ru/concept/show/1234</core:url>
#
# <core:url>http://libmeta.ru/concept/1234</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Устойчивость_при_постоянно_действующих_возмущениях">
#
# <core:url>http://libmeta.ru/concept/show/1247</core:url>
#
# <core:url>http://libmeta.ru/concept/1247</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Симметрическая_разность">
#
# <core:url>http://libmeta.ru/concept/show/1280</core:url>
#
# <core:url>http://libmeta.ru/concept/1280</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Билинейный_дифференциал">
#
# <core:url>http://libmeta.ru/concept/show/1320</core:url>
#
# <core:url>http://libmeta.ru/concept/1320</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Программирование_математическое">
#
# <core:url>http://libmeta.ru/concept/show/1341</core:url>
#
# <core:url>http://libmeta.ru/concept/1341</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Нётерово_интегральное_уравнение">
#
# <core:url>http://libmeta.ru/concept/show/1363</core:url>
#
# <core:url>http://libmeta.ru/concept/1363</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Дифференциальное_уравнение_с_частными_производными">
#
# <core:url>http://libmeta.ru/concept/show/1380</core:url>
#
# <core:url>http://libmeta.ru/concept/1380</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Положительно_определенная_функция">
#
# <core:url>http://libmeta.ru/concept/show/1397</core:url>
#
# <core:url>http://libmeta.ru/concept/1397</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Непрерывная_серия_представлений">
#
# <core:url>http://libmeta.ru/concept/show/1419</core:url>
#
# <core:url>http://libmeta.ru/concept/1419</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Маркова_система_функций">
#
# <core:url>http://libmeta.ru/concept/show/1464</core:url>
#
# <core:url>http://libmeta.ru/concept/1464</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Полного_накопления_точка">
#
# <core:url>http://libmeta.ru/concept/show/874</core:url>
#
# <core:url>http://libmeta.ru/concept/874</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гипоциклоида">
#
# <core:url>http://libmeta.ru/concept/show/2335</core:url>
#
# <core:url>http://libmeta.ru/concept/2335</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Хаусдорфа_-_юнга_неравенства">
#
# <core:url>http://libmeta.ru/concept/show/2394</core:url>
#
# <core:url>http://libmeta.ru/concept/2394</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Выборочная_функция">
#
# <core:url>http://libmeta.ru/concept/show/2446</core:url>
#
# <core:url>http://libmeta.ru/concept/2446</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Горенштейна_кольцо">
#
# <core:url>http://libmeta.ru/concept/show/2463</core:url>
#
# <core:url>http://libmeta.ru/concept/2463</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Проективное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/2509</core:url>
#
# <core:url>http://libmeta.ru/concept/2509</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гильбертово_пространство">
#
# <core:url>http://libmeta.ru/concept/show/2572</core:url>
#
# <core:url>http://libmeta.ru/concept/2572</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Центральные_показатели">
#
# <core:url>http://libmeta.ru/concept/show/2594</core:url>
#
# <core:url>http://libmeta.ru/concept/2594</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Бесселя_функции">
#
# <core:url>http://libmeta.ru/concept/show/2614</core:url>
#
# <core:url>http://libmeta.ru/concept/2614</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Оптимальное_управление_позиционное">
#
# <core:url>http://libmeta.ru/concept/show/2630</core:url>
#
# <core:url>http://libmeta.ru/concept/2630</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Окаймление_пространства">
#
# <core:url>http://libmeta.ru/concept/show/2652</core:url>
#
# <core:url>http://libmeta.ru/concept/2652</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кондуктор">
#
# <core:url>http://libmeta.ru/concept/show/673</core:url>
#
# <core:url>http://libmeta.ru/concept/673</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Дифференциальное_уравнение_с_частными_производными_второго_порядка">
#
# <core:url>http://libmeta.ru/concept/show/2749</core:url>
#
# <core:url>http://libmeta.ru/concept/2749</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Структурно_упорядоченная_группа">
#
# <core:url>http://libmeta.ru/concept/show/649</core:url>
#
# <core:url>http://libmeta.ru/concept/649</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Атомарное_кольцо">
#
# <core:url>http://libmeta.ru/concept/show/1740</core:url>
#
# <core:url>http://libmeta.ru/concept/1740</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Формальных_систем_эквивалентность">
#
# <core:url>http://libmeta.ru/concept/show/1756</core:url>
#
# <core:url>http://libmeta.ru/concept/1756</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Вольтерра_оператор">
#
# <core:url>http://libmeta.ru/concept/show/1778</core:url>
#
# <core:url>http://libmeta.ru/concept/1778</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Типично_вещественная_функция">
#
# <core:url>http://libmeta.ru/concept/show/1809</core:url>
#
# <core:url>http://libmeta.ru/concept/1809</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Поток">
#
# <core:url>http://libmeta.ru/concept/show/1272</core:url>
#
# <core:url>http://libmeta.ru/concept/1272</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Выпуклая_функция">
#
# <core:url>http://libmeta.ru/concept/show/976</core:url>
#
# <core:url>http://libmeta.ru/concept/976</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Присоединенное_представление">
#
# <core:url>http://libmeta.ru/concept/show/1141</core:url>
#
# <core:url>http://libmeta.ru/concept/1141</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Первый_интеграл">
#
# <core:url>http://libmeta.ru/concept/show/2557</core:url>
#
# <core:url>http://libmeta.ru/concept/2557</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Лапласа_интеграл">
#
# <core:url>http://libmeta.ru/concept/show/592</core:url>
#
# <core:url>http://libmeta.ru/concept/592</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кремоново_преобразование">
#
# <core:url>http://libmeta.ru/concept/show/2376</core:url>
#
# <core:url>http://libmeta.ru/concept/2376</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кравчука_многочлены">
#
# <core:url>http://libmeta.ru/concept/show/2691</core:url>
#
# <core:url>http://libmeta.ru/concept/2691</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Векторное_поле">
#
# <core:url>http://libmeta.ru/concept/show/2494</core:url>
#
# <core:url>http://libmeta.ru/concept/2494</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Альванезе_многообразие">
#
# <core:url>http://libmeta.ru/concept/show/2529</core:url>
#
# <core:url>http://libmeta.ru/concept/2529</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гиперкомплексного_переменного_функция">
#
# <core:url>http://libmeta.ru/concept/show/1830</core:url>
#
# <core:url>http://libmeta.ru/concept/1830</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Абстракция_актуальной_бесконечности">
#
# <core:url>http://libmeta.ru/concept/show/1862</core:url>
#
# <core:url>http://libmeta.ru/concept/1862</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Частично_рекурсивный_оператор">
#
# <core:url>http://libmeta.ru/concept/show/1886</core:url>
#
# <core:url>http://libmeta.ru/concept/1886</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Главное_однородное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/1946</core:url>
#
# <core:url>http://libmeta.ru/concept/1946</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Заполненное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/1979</core:url>
#
# <core:url>http://libmeta.ru/concept/1979</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Индуктивный_предел">
#
# <core:url>http://libmeta.ru/concept/show/1999</core:url>
#
# <core:url>http://libmeta.ru/concept/1999</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Совместность_методов_суммирования">
#
# <core:url>http://libmeta.ru/concept/show/2021</core:url>
#
# <core:url>http://libmeta.ru/concept/2021</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Модулей_категория">
#
# <core:url>http://libmeta.ru/concept/show/2045</core:url>
#
# <core:url>http://libmeta.ru/concept/2045</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гиперболической_метрики_принцип">
#
# <core:url>http://libmeta.ru/concept/show/2062</core:url>
#
# <core:url>http://libmeta.ru/concept/2062</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Релятивистской_термодинамики_математические_задачи">
#
# <core:url>http://libmeta.ru/concept/show/2074</core:url>
#
# <core:url>http://libmeta.ru/concept/2074</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Динамические_задачи_теории_упругости">
#
# <core:url>http://libmeta.ru/concept/show/2103</core:url>
#
# <core:url>http://libmeta.ru/concept/2103</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Толерантный_интервал">
#
# <core:url>http://libmeta.ru/concept/show/2159</core:url>
#
# <core:url>http://libmeta.ru/concept/2159</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Конформное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/2176</core:url>
#
# <core:url>http://libmeta.ru/concept/2176</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Диффузионное_приближение">
#
# <core:url>http://libmeta.ru/concept/show/2229</core:url>
#
# <core:url>http://libmeta.ru/concept/2229</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Диофантовы_проблемы_аддитивного_типа">
#
# <core:url>http://libmeta.ru/concept/show/2260</core:url>
#
# <core:url>http://libmeta.ru/concept/2260</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Отделимое_пополнение_кольца">
#
# <core:url>http://libmeta.ru/concept/show/2280</core:url>
#
# <core:url>http://libmeta.ru/concept/2280</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Логическое_следствие">
#
# <core:url>http://libmeta.ru/concept/show/2314</core:url>
#
# <core:url>http://libmeta.ru/concept/2314</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Ньютона-_котеса_квадратурная_формула">
#
# <core:url>http://libmeta.ru/concept/show/2705</core:url>
#
# <core:url>http://libmeta.ru/concept/2705</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Бейесовский_подход">
#
# <core:url>http://libmeta.ru/concept/show/2717</core:url>
#
# <core:url>http://libmeta.ru/concept/2717</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Сильно_непрерывная_полугруппа">
#
# <core:url>http://libmeta.ru/concept/show/2757</core:url>
#
# <core:url>http://libmeta.ru/concept/2757</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Продолжаемость_решений_дифференциальных_уравнений">
#
# <core:url>http://libmeta.ru/concept/show/2786</core:url>
#
# <core:url>http://libmeta.ru/concept/2786</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Достижимая_граничная_точка">
#
# <core:url>http://libmeta.ru/concept/show/2812</core:url>
#
# <core:url>http://libmeta.ru/concept/2812</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Многомерная_геометрия">
#
# <core:url>http://libmeta.ru/concept/show/3418</core:url>
#
# <core:url>http://libmeta.ru/concept/3418</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Спектральная_последовательность">
#
# <core:url>http://libmeta.ru/concept/show/3434</core:url>
#
# <core:url>http://libmeta.ru/concept/3434</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Фоккера_-_планка_уравнение">
#
# <core:url>http://libmeta.ru/concept/show/3497</core:url>
#
# <core:url>http://libmeta.ru/concept/3497</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Обобщенные_теории_когомологии">
#
# <core:url>http://libmeta.ru/concept/show/3516</core:url>
#
# <core:url>http://libmeta.ru/concept/3516</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кососимметрическая_матрица">
#
# <core:url>http://libmeta.ru/concept/show/3532</core:url>
#
# <core:url>http://libmeta.ru/concept/3532</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кристаллографическая_группа">
#
# <core:url>http://libmeta.ru/concept/show/3554</core:url>
#
# <core:url>http://libmeta.ru/concept/3554</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гильбертово_пространство_с_индефинитной_метрикой">
#
# <core:url>http://libmeta.ru/concept/show/3574</core:url>
#
# <core:url>http://libmeta.ru/concept/3574</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Звездообразная_область">
#
# <core:url>http://libmeta.ru/concept/show/3611</core:url>
#
# <core:url>http://libmeta.ru/concept/3611</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Мультиоператорная_группа">
#
# <core:url>http://libmeta.ru/concept/show/3628</core:url>
#
# <core:url>http://libmeta.ru/concept/3628</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гармоническая_форма">
#
# <core:url>http://libmeta.ru/concept/show/3673</core:url>
#
# <core:url>http://libmeta.ru/concept/3673</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Производный_автоморфизм">
#
# <core:url>http://libmeta.ru/concept/show/706</core:url>
#
# <core:url>http://libmeta.ru/concept/706</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Алеф-нуль">
#
# <core:url>http://libmeta.ru/concept/show/717</core:url>
#
# <core:url>http://libmeta.ru/concept/717</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Свободное_произведение">
#
# <core:url>http://libmeta.ru/concept/show/2770</core:url>
#
# <core:url>http://libmeta.ru/concept/2770</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Вырожденная_гипергеометрическая_функция">
#
# <core:url>http://libmeta.ru/concept/show/2850</core:url>
#
# <core:url>http://libmeta.ru/concept/2850</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Хефлигера_структура">
#
# <core:url>http://libmeta.ru/concept/show/2905</core:url>
#
# <core:url>http://libmeta.ru/concept/2905</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Параболическая_подалгебра">
#
# <core:url>http://libmeta.ru/concept/show/2921</core:url>
#
# <core:url>http://libmeta.ru/concept/2921</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Экстремальные_задачи">
#
# <core:url>http://libmeta.ru/concept/show/2940</core:url>
#
# <core:url>http://libmeta.ru/concept/2940</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Бернштейна_интерполяционный_процесс">
#
# <core:url>http://libmeta.ru/concept/show/2957</core:url>
#
# <core:url>http://libmeta.ru/concept/2957</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Фабера_-_шаудера_система">
#
# <core:url>http://libmeta.ru/concept/show/2983</core:url>
#
# <core:url>http://libmeta.ru/concept/2983</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Приближение_функций_комплексного_переменного">
#
# <core:url>http://libmeta.ru/concept/show/2997</core:url>
#
# <core:url>http://libmeta.ru/concept/2997</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Дискретного_нормирования_кольцо">
#
# <core:url>http://libmeta.ru/concept/show/3040</core:url>
#
# <core:url>http://libmeta.ru/concept/3040</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Абсолютный_момент">
#
# <core:url>http://libmeta.ru/concept/show/3081</core:url>
#
# <core:url>http://libmeta.ru/concept/3081</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#График">
#
# <core:url>http://libmeta.ru/concept/show/1535</core:url>
#
# <core:url>http://libmeta.ru/concept/1535</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Универсальная_функция">
#
# <core:url>http://libmeta.ru/concept/show/1848</core:url>
#
# <core:url>http://libmeta.ru/concept/1848</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Льенара_-_шипара_критерии">
#
# <core:url>http://libmeta.ru/concept/show/3654</core:url>
#
# <core:url>http://libmeta.ru/concept/3654</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Линейчатая_поверхность">
#
# <core:url>http://libmeta.ru/concept/show/3458</core:url>
#
# <core:url>http://libmeta.ru/concept/3458</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Импликативная_нормальная_форма">
#
# <core:url>http://libmeta.ru/concept/show/1925</core:url>
#
# <core:url>http://libmeta.ru/concept/1925</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Упругости_математическая_теория">
#
# <core:url>http://libmeta.ru/concept/show/3094</core:url>
#
# <core:url>http://libmeta.ru/concept/3094</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Ограниченно-детерминированная_функция">
#
# <core:url>http://libmeta.ru/concept/show/3135</core:url>
#
# <core:url>http://libmeta.ru/concept/3135</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Структурный_изоморфизм">
#
# <core:url>http://libmeta.ru/concept/show/3214</core:url>
#
# <core:url>http://libmeta.ru/concept/3214</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Эйленберга_-_маклейна_пространство">
#
# <core:url>http://libmeta.ru/concept/show/3254</core:url>
#
# <core:url>http://libmeta.ru/concept/3254</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Ковариантный_тензор">
#
# <core:url>http://libmeta.ru/concept/show/3276</core:url>
#
# <core:url>http://libmeta.ru/concept/3276</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кососимметрический_тензор">
#
# <core:url>http://libmeta.ru/concept/show/3277</core:url>
#
# <core:url>http://libmeta.ru/concept/3277</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Дифференцирование_численное">
#
# <core:url>http://libmeta.ru/concept/show/3295</core:url>
#
# <core:url>http://libmeta.ru/concept/3295</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Ассоциированная_функция">
#
# <core:url>http://libmeta.ru/concept/show/3318</core:url>
#
# <core:url>http://libmeta.ru/concept/3318</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Векторное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/3337</core:url>
#
# <core:url>http://libmeta.ru/concept/3337</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Двойного_слоя_потенциал">
#
# <core:url>http://libmeta.ru/concept/show/3374</core:url>
#
# <core:url>http://libmeta.ru/concept/3374</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Когомологий_банаховых_алгебр">
#
# <core:url>http://libmeta.ru/concept/show/3393</core:url>
#
# <core:url>http://libmeta.ru/concept/3393</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Валле_пуссена_многоточечная_задача">
#
# <core:url>http://libmeta.ru/concept/show/3710</core:url>
#
# <core:url>http://libmeta.ru/concept/3710</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Аналитическая_функция_абстрактная">
#
# <core:url>http://libmeta.ru/concept/show/3734</core:url>
#
# <core:url>http://libmeta.ru/concept/3734</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Вполне_геодезическое_многообразие">
#
# <core:url>http://libmeta.ru/concept/show/3743</core:url>
#
# <core:url>http://libmeta.ru/concept/3743</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Градиентное_преобразование">
#
# <core:url>http://libmeta.ru/concept/show/3778</core:url>
#
# <core:url>http://libmeta.ru/concept/3778</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Механических_квадратур_метод">
#
# <core:url>http://libmeta.ru/concept/show/3798</core:url>
#
# <core:url>http://libmeta.ru/concept/3798</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Евклидово_поле">
#
# <core:url>http://libmeta.ru/concept/show/2877</core:url>
#
# <core:url>http://libmeta.ru/concept/2877</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Асимптотическая_пренебрегаемость">
#
# <core:url>http://libmeta.ru/concept/show/3476</core:url>
#
# <core:url>http://libmeta.ru/concept/3476</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Отделимости_аксиома">
#
# <core:url>http://libmeta.ru/concept/show/3592</core:url>
#
# <core:url>http://libmeta.ru/concept/3592</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Равномерная_ограниченность">
#
# <core:url>http://libmeta.ru/concept/show/3020</core:url>
#
# <core:url>http://libmeta.ru/concept/3020</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Исключительное_подмногообразие">
#
# <core:url>http://libmeta.ru/concept/show/4640</core:url>
#
# <core:url>http://libmeta.ru/concept/4640</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Асимптотически_устойчивое_решение">
#
# <core:url>http://libmeta.ru/concept/show/4735</core:url>
#
# <core:url>http://libmeta.ru/concept/4735</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Двумерное_многообразие_ограниченной_кривизны">
#
# <core:url>http://libmeta.ru/concept/show/4759</core:url>
#
# <core:url>http://libmeta.ru/concept/4759</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Дифференциальное_уравнение_в_полных_дифференциалах">
#
# <core:url>http://libmeta.ru/concept/show/3822</core:url>
#
# <core:url>http://libmeta.ru/concept/3822</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Аналитическая_модель_языка">
#
# <core:url>http://libmeta.ru/concept/show/3854</core:url>
#
# <core:url>http://libmeta.ru/concept/3854</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Предельное_множество">
#
# <core:url>http://libmeta.ru/concept/show/3898</core:url>
#
# <core:url>http://libmeta.ru/concept/3898</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Трансверсально_эллиптический_оператор">
#
# <core:url>http://libmeta.ru/concept/show/3914</core:url>
#
# <core:url>http://libmeta.ru/concept/3914</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Дифференциальное_уравнение_с_отклоняющимся_аргументом">
#
# <core:url>http://libmeta.ru/concept/show/3939</core:url>
#
# <core:url>http://libmeta.ru/concept/3939</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Матричная_игра">
#
# <core:url>http://libmeta.ru/concept/show/3973</core:url>
#
# <core:url>http://libmeta.ru/concept/3973</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Клейна_интерпретация">
#
# <core:url>http://libmeta.ru/concept/show/4015</core:url>
#
# <core:url>http://libmeta.ru/concept/4015</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Линейное_дифференциальное_уравнение_в_банаховом_пространстве">
#
# <core:url>http://libmeta.ru/concept/show/4027</core:url>
#
# <core:url>http://libmeta.ru/concept/4027</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Фробениуса_теорема">
#
# <core:url>http://libmeta.ru/concept/show/4042</core:url>
#
# <core:url>http://libmeta.ru/concept/4042</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Арифметика_формальная">
#
# <core:url>http://libmeta.ru/concept/show/4138</core:url>
#
# <core:url>http://libmeta.ru/concept/4138</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Вариации_среднего_значения_теорема">
#
# <core:url>http://libmeta.ru/concept/show/4171</core:url>
#
# <core:url>http://libmeta.ru/concept/4171</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Проективное_мероопределение">
#
# <core:url>http://libmeta.ru/concept/show/4195</core:url>
#
# <core:url>http://libmeta.ru/concept/4195</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Аппроксимация_дифференциальной_краевой_задачи_разностной">
#
# <core:url>http://libmeta.ru/concept/show/4245</core:url>
#
# <core:url>http://libmeta.ru/concept/4245</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Тупиковая_дизъюнктивная_нормальная_форма">
#
# <core:url>http://libmeta.ru/concept/show/4269</core:url>
#
# <core:url>http://libmeta.ru/concept/4269</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Нульмерное_пространство">
#
# <core:url>http://libmeta.ru/concept/show/4297</core:url>
#
# <core:url>http://libmeta.ru/concept/4297</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Дирихле_разрывный_множитель">
#
# <core:url>http://libmeta.ru/concept/show/4315</core:url>
#
# <core:url>http://libmeta.ru/concept/4315</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кортевега_-_де_фриса_уравнение">
#
# <core:url>http://libmeta.ru/concept/show/4335</core:url>
#
# <core:url>http://libmeta.ru/concept/4335</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Минимизация_вычислительной_работы">
#
# <core:url>http://libmeta.ru/concept/show/4358</core:url>
#
# <core:url>http://libmeta.ru/concept/4358</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Веиерштрасса_эллиптические_функции">
#
# <core:url>http://libmeta.ru/concept/show/4378</core:url>
#
# <core:url>http://libmeta.ru/concept/4378</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Перрона_-_стилтьеса_интеграл">
#
# <core:url>http://libmeta.ru/concept/show/3192</core:url>
#
# <core:url>http://libmeta.ru/concept/3192</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кольцо_с_делением">
#
# <core:url>http://libmeta.ru/concept/show/4666</core:url>
#
# <core:url>http://libmeta.ru/concept/4666</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Галуа_теории_обратная_задача">
#
# <core:url>http://libmeta.ru/concept/show/3355</core:url>
#
# <core:url>http://libmeta.ru/concept/3355</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Вырожденное_эллиптическое_уравнение">
#
# ...
#
# <core:url>http://libmeta.ru/concept/show/1992</core:url>
#
# <core:url>http://libmeta.ru/concept/1992</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Стилтьеса_преобразование">
#
# <core:url>http://libmeta.ru/concept/show/601</core:url>
#
# <core:url>http://libmeta.ru/concept/601</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Стеклова_функция">
#
# <core:url>http://libmeta.ru/concept/show/5862</core:url>
#
# <core:url>http://libmeta.ru/concept/5862</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Унипотентная_группа">
#
# <core:url>http://libmeta.ru/concept/show/5954</core:url>
#
# <core:url>http://libmeta.ru/concept/5954</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Совершенное_число">
#
# <core:url>http://libmeta.ru/concept/show/6472</core:url>
#
# <core:url>http://libmeta.ru/concept/6472</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Совершенное_поле">
#
# <core:url>http://libmeta.ru/concept/show/917</core:url>
#
# <core:url>http://libmeta.ru/concept/917</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Сеть">
#
# <core:url>http://libmeta.ru/concept/show/802</core:url>
#
# <core:url>http://libmeta.ru/concept/802</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Тригонометрических_сумм_метод">
#
# <core:url>http://libmeta.ru/concept/show/4273</core:url>
#
# <core:url>http://libmeta.ru/concept/4273</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Треугольная_матрица">
#
# <core:url>http://libmeta.ru/concept/show/676</core:url>
#
# <core:url>http://libmeta.ru/concept/676</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Трансцендентности_мера">
#
# <core:url>http://libmeta.ru/concept/show/2992</core:url>
#
# <core:url>http://libmeta.ru/concept/2992</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Рациональное_число">
#
# <core:url>http://libmeta.ru/concept/show/2628</core:url>
#
# <core:url>http://libmeta.ru/concept/2628</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Стеклова_проблемы">
#
# <core:url>http://libmeta.ru/concept/show/4329</core:url>
#
# <core:url>http://libmeta.ru/concept/4329</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Случайных_процессов_прогнозирование">
#
# <core:url>http://libmeta.ru/concept/show/5851</core:url>
#
# <core:url>http://libmeta.ru/concept/5851</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Случайный_точечный_процесс">
#
# <core:url>http://libmeta.ru/concept/show/3224</core:url>
#
# <core:url>http://libmeta.ru/concept/3224</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Преобразований_полугруппа">
#
# <core:url>http://libmeta.ru/concept/show/4800</core:url>
#
# <core:url>http://libmeta.ru/concept/4800</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Транслятивность_метода_суммирования">
#
# <core:url>http://libmeta.ru/concept/show/5786</core:url>
#
# <core:url>http://libmeta.ru/concept/5786</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Тетраэдр">
#
# <core:url>http://libmeta.ru/concept/show/4446</core:url>
#
# <core:url>http://libmeta.ru/concept/4446</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Статистическое_оценивание">
#
# <core:url>http://libmeta.ru/concept/show/5059</core:url>
#
# <core:url>http://libmeta.ru/concept/5059</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Серра_подкатегория">
#
# <core:url>http://libmeta.ru/concept/show/1993</core:url>
#
# <core:url>http://libmeta.ru/concept/1993</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Свободный_модуль">
#
# <core:url>http://libmeta.ru/concept/show/2034</core:url>
#
# <core:url>http://libmeta.ru/concept/2034</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Радикальная_ось">
#
# <core:url>http://libmeta.ru/concept/show/4778</core:url>
#
# <core:url>http://libmeta.ru/concept/4778</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Спуска_метод">
#
# <core:url>http://libmeta.ru/concept/show/2219</core:url>
#
# <core:url>http://libmeta.ru/concept/2219</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Свободная_ассоциативная_алгебра">
#
# <core:url>http://libmeta.ru/concept/show/4115</core:url>
#
# <core:url>http://libmeta.ru/concept/4115</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Скрещенное_произведение">
#
# <core:url>http://libmeta.ru/concept/show/1683</core:url>
#
# <core:url>http://libmeta.ru/concept/1683</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Сверхразрешимая_группа">
#
# <core:url>http://libmeta.ru/concept/show/1725</core:url>
#
# <core:url>http://libmeta.ru/concept/1725</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Симплектическая_группа">
#
# <core:url>http://libmeta.ru/concept/show/2382</core:url>
#
# <core:url>http://libmeta.ru/concept/2382</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Рефлективная_подкатегория">
#
# <core:url>http://libmeta.ru/concept/show/3730</core:url>
#
# <core:url>http://libmeta.ru/concept/3730</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Релятивная_геометрия">
#
# <core:url>http://libmeta.ru/concept/show/1933</core:url>
#
# <core:url>http://libmeta.ru/concept/1933</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Рекурсивное_отношение">
#
# <core:url>http://libmeta.ru/concept/show/2349</core:url>
#
# <core:url>http://libmeta.ru/concept/2349</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Простая_конечная_группа">
#
# <core:url>http://libmeta.ru/concept/show/5106</core:url>
#
# <core:url>http://libmeta.ru/concept/5106</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Регрессии_поверхность">
#
# <core:url>http://libmeta.ru/concept/show/3552</core:url>
#
# <core:url>http://libmeta.ru/concept/3552</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Преследования_игра">
#
# <core:url>http://libmeta.ru/concept/show/5144</core:url>
#
# <core:url>http://libmeta.ru/concept/5144</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Распределения_функция">
#
# <core:url>http://libmeta.ru/concept/show/3473</core:url>
#
# <core:url>http://libmeta.ru/concept/3473</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Рамануджана_гипотеза">
#
# <core:url>http://libmeta.ru/concept/show/5882</core:url>
#
# <core:url>http://libmeta.ru/concept/5882</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Разрешимое_многообразие">
#
# <core:url>http://libmeta.ru/concept/show/1313</core:url>
#
# <core:url>http://libmeta.ru/concept/1313</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Полугруппа_с_условием_конечности">
#
# <core:url>http://libmeta.ru/concept/show/3689</core:url>
#
# <core:url>http://libmeta.ru/concept/3689</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Полиномиальный_коэффициент">
#
# <core:url>http://libmeta.ru/concept/show/4695</core:url>
#
# <core:url>http://libmeta.ru/concept/4695</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Подстановка">
#
# <core:url>http://libmeta.ru/concept/show/2344</core:url>
#
# <core:url>http://libmeta.ru/concept/2344</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Квадратичное_отклонение">
#
# <core:url>http://libmeta.ru/concept/show/3839</core:url>
#
# <core:url>http://libmeta.ru/concept/3839</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Плотность_последовательности">
#
# <core:url>http://libmeta.ru/concept/show/2668</core:url>
#
# <core:url>http://libmeta.ru/concept/2668</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Параболический_цилиндр">
#
# <core:url>http://libmeta.ru/concept/show/1217</core:url>
#
# <core:url>http://libmeta.ru/concept/1217</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Отсчета_система">
#
# <core:url>http://libmeta.ru/concept/show/3608</core:url>
#
# <core:url>http://libmeta.ru/concept/3608</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Интегрирование_дифференциальных_уравнении_в_замкнутой_форме">
#
# <core:url>http://libmeta.ru/concept/show/4736</core:url>
#
# <core:url>http://libmeta.ru/concept/4736</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Осциллятор_гармонический">
#
# <core:url>http://libmeta.ru/concept/show/5426</core:url>
#
# <core:url>http://libmeta.ru/concept/5426</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Интегральный_гиперболический_синус">
#
# <core:url>http://libmeta.ru/concept/show/1768</core:url>
#
# <core:url>http://libmeta.ru/concept/1768</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Линейный_функционал">
#
# <core:url>http://libmeta.ru/concept/show/1626</core:url>
#
# <core:url>http://libmeta.ru/concept/1626</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Икосаэдра_пространство">
#
# <core:url>http://libmeta.ru/concept/show/2569</core:url>
#
# <core:url>http://libmeta.ru/concept/2569</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Билинейное_отображение">
#
# <core:url>http://libmeta.ru/concept/show/3279</core:url>
#
# <core:url>http://libmeta.ru/concept/3279</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Ортогональная_группа">
#
# <core:url>http://libmeta.ru/concept/show/1945</core:url>
#
# <core:url>http://libmeta.ru/concept/1945</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Двойная_последовательность">
#
# <core:url>http://libmeta.ru/concept/show/5522</core:url>
#
# <core:url>http://libmeta.ru/concept/5522</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Нормальное_уравнение">
#
# <core:url>http://libmeta.ru/concept/show/5224</core:url>
#
# <core:url>http://libmeta.ru/concept/5224</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Асимптотически_эффективная_оценка">
#
# <core:url>http://libmeta.ru/concept/show/5324</core:url>
#
# <core:url>http://libmeta.ru/concept/5324</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Нормальная_плоскость">
#
# <core:url>http://libmeta.ru/concept/show/1192</core:url>
#
# <core:url>http://libmeta.ru/concept/1192</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Данжуа_интеграл">
#
# <core:url>http://libmeta.ru/concept/show/3190</core:url>
#
# <core:url>http://libmeta.ru/concept/3190</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Непредикативное_определение">
#
# <core:url>http://libmeta.ru/concept/show/6106</core:url>
#
# <core:url>http://libmeta.ru/concept/6106</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гильберта_-_шмидта_норма">
#
# <core:url>http://libmeta.ru/concept/show/1321</core:url>
#
# <core:url>http://libmeta.ru/concept/1321</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Абеля-пуассона_метод_суммирования">
#
# <core:url>http://libmeta.ru/concept/show/5811</core:url>
#
# <core:url>http://libmeta.ru/concept/5811</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Гаусса_квадратурная_формула">
#
# <core:url>http://libmeta.ru/concept/show/2709</core:url>
#
# <core:url>http://libmeta.ru/concept/2709</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Наименее_уклоняющийся_от_нуля_многочлен">
#
# <core:url>http://libmeta.ru/concept/show/4628</core:url>
#
# <core:url>http://libmeta.ru/concept/4628</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Мономорфизм">
#
# <core:url>http://libmeta.ru/concept/show/2307</core:url>
#
# <core:url>http://libmeta.ru/concept/2307</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Менелая_теорема">
#
# <core:url>http://libmeta.ru/concept/show/4075</core:url>
#
# <core:url>http://libmeta.ru/concept/4075</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Линейное_уравнение">
#
# <core:url>http://libmeta.ru/concept/show/2275</core:url>
#
# <core:url>http://libmeta.ru/concept/2275</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Лебега_интеграл">
#
# <core:url>http://libmeta.ru/concept/show/4126</core:url>
#
# <core:url>http://libmeta.ru/concept/4126</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Лёвенхейма_-_сколема_теорема">
#
# <core:url>http://libmeta.ru/concept/show/6438</core:url>
#
# <core:url>http://libmeta.ru/concept/6438</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Линейных_алгебраических_групп_арифметическая_теория">
#
# <core:url>http://libmeta.ru/concept/show/3096</core:url>
#
# <core:url>http://libmeta.ru/concept/3096</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Векторное_исчисление">
#
# <core:url>http://libmeta.ru/concept/show/2856</core:url>
#
# <core:url>http://libmeta.ru/concept/2856</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Конструктивного_подбора_принцип">
#
# <core:url>http://libmeta.ru/concept/show/1860</core:url>
#
# <core:url>http://libmeta.ru/concept/1860</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Конгруэнц-проблема">
#
# <core:url>http://libmeta.ru/concept/show/5182</core:url>
#
# <core:url>http://libmeta.ru/concept/5182</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Компактный_оператор">
#
# <core:url>http://libmeta.ru/concept/show/1618</core:url>
#
# <core:url>http://libmeta.ru/concept/1618</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Кватернионов_группа">
#
# <core:url>http://libmeta.ru/concept/show/3029</core:url>
#
# <core:url>http://libmeta.ru/concept/3029</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Квадратичный_вычет">
#
# <core:url>http://libmeta.ru/concept/show/2092</core:url>
#
# <core:url>http://libmeta.ru/concept/2092</core:url>
#
# </lbm:Concept>
#
# <lbm:Concept rdf:about="http://libmeta.ru/thesaurus/mathencyclopedia#Аналитическая_теория_дифференциальных_уравнений">
#
# <core:url>http://libmeta.ru/concept/show/2267</core:url>
#
# <core:url>http://libmeta.ru/concept/2267</core:url>
#
# </lbm:Concept>
#
# </lbm:Thesaurus>
#
# </rdf:RDF>
# 0

# %%
norm_library = []
libmeta = []  # a list of string representing the latex document in python
x = 0

with open('libmeta.txt', 'UTF-8') as libmeta:
    line_type = 0
    for line in libmeta:
        #print line
        if line_type == 1: # this string contain link with 'show'
            line_type = 0
            link_num = line[41:-12]
            c = nitem.count(" ")
            if c == 0:
                norm_library.append([nitem.normal_form, link_num, item])
            else:
                nitem_lst = nitem.split()
                nn_lst = []
                for word in nitem_lst: # create norm_lst and norm_lst_num
                    w = morph.parse(word.decode('utf-8'))[0]
                    nn_lst.append(w.normal_form)
                nitem = " ".join(nitem_lst)
                norm_library.append([nitem, link_num, item])
                while c > 0:
                    d = nitem.find(" ")
                    nitem = nitem[d+1:] + ' ' + nitem[:d]
                    norm_library.append([nitem, link_num, item])
                    c = c - 1
        elif (line.find("<lbm:Concept rdf:about") == 0) and (line[-2] == '>'):
            line_type = 1 # this string contain term
            y = line.find("#")
            keyword = unicode(line[y+1:-3], 'utf-8')
            if len(keyword) > 0:
                item = keyword.replace("_", " ").replace(" - ", "-").replace('\n', ' ').lower()
                if (len(item) > 0) and (item.find('<') == -1):
                    x = x + 1
                    nitem = morph.parse(item)[0]
norm_library.sort(key=lambda x: 0 - x[0].count(" "))
print x
#norm_library
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-244-53e23aa42d54> in <module>()
#      34                     x = x + 1
#      35                     nitem = morph.parse(item)[0]
# ---> 36                     c = nitem.count(" ")
#      37 norm_library.sort(key=lambda x: 0 - x[0].count(" "))
#      38 print x
#
# /usr/local/lib/python2.7/site-packages/pymorphy2/tagset.pyc in __eq__(self, other)
#     357
#     358     def __eq__(self, other):
# --> 359         return self._grammemes_tuple == other._grammemes_tuple
#     360
#     361     def __ne__(self, other):
#
# AttributeError: 'str' object has no attribute '_grammemes_tuple'

# %%
libmeta = []  # a list of string representing the libmeta.txt
norm_library = [] # list of keywords in normal form
                  # with different word order for multi-word terms
                  # order by amount of words
with open('libmeta.txt', 'UTF-8') as libmeta:
    line_type = 0
    for line in libmeta:
        if line_type == 1: # this string contain link with 'show'
            line_type = 0
            link_num = line[41:-12]
            nitem = nitem.normal_form
            c = nitem.count(" ")
            if c == 0:
                norm_library.append([nitem, link_num, item])
            else:
                n_lst = nitem.split()
                nitem = ""
                for word in n_lst:
                    w = morph.parse(word)[0]
                    nitem = nitem + ' ' + w.normal_form
                nitem = nitem[1:]
                norm_library.append([nitem, link_num, item])
            while c > 0:
                d = nitem.find(" ")
                nitem = nitem[d+1:] + ' ' + nitem[:d]
                norm_library.append([nitem, link_num, item])
                c = c - 1
        elif (line.find("<lbm:Concept rdf:about") == 0) and (line[-2] == '>'):
            line_type = 1 # this string contain term
            y = line.find("#")
            keyword = unicode(line[y+1:-3], 'utf-8')
            x = x + 1
            if len(keyword) > 0:
                item = keyword.replace("_", " ").replace(" - ", "-").lower()
                nitem = morph.parse(item)[0]
norm_library.sort(key=lambda x: 0 - x[0].count(" "))

# %%
for nitem in norm_library:
    print nitem[0]
# Out:
# смешанный и краевой задача для гиперболический уравнение и система
# и краевой задача для гиперболический уравнение и система смешанный
# краевой задача для гиперболический уравнение и система смешанный и
# задача для гиперболический уравнение и система смешанный и краевой
# для гиперболический уравнение и система смешанный и краевой задача
# гиперболический уравнение и система смешанный и краевой задача для
# уравнение и система смешанный и краевой задача для гиперболический
# и система смешанный и краевой задача для гиперболический уравнение
# система смешанный и краевой задача для гиперболический уравнение и
# смешанный и краевой задача для параболический уравнение и система
# и краевой задача для параболический уравнение и система смешанный
# краевой задача для параболический уравнение и система смешанный и
# задача для параболический уравнение и система смешанный и краевой
# для параболический уравнение и система смешанный и краевой задача
# параболический уравнение и система смешанный и краевой задача для
# уравнение и система смешанный и краевой задача для параболический
# и система смешанный и краевой задача для параболический уравнение
# система смешанный и краевой задача для параболический уравнение и
# линейный система дифференциальный уравнение с почти периодический коэффициент
# система дифференциальный уравнение с почти периодический коэффициент линейный
# дифференциальный уравнение с почти периодический коэффициент линейный система
# уравнение с почти периодический коэффициент линейный система дифференциальный
# с почти периодический коэффициент линейный система дифференциальный уравнение
# почти периодический коэффициент линейный система дифференциальный уравнение с
# периодический коэффициент линейный система дифференциальный уравнение с почти
# коэффициент линейный система дифференциальный уравнение с почти периодический
# дифференциальный уравнение с частный производная второй порядок
# уравнение с частный производная второй порядок дифференциальный
# с частный производная второй порядок дифференциальный уравнение
# частный производная второй порядок дифференциальный уравнение с
# производная второй порядок дифференциальный уравнение с частный
# второй порядок дифференциальный уравнение с частный производная
# порядок дифференциальный уравнение с частный производная второй
# ветвиться процесс с конечный число тип частица
# процесс с конечный число тип частица ветвиться
# с конечный число тип частица ветвиться процесс
# конечный число тип частица ветвиться процесс с
# число тип частица ветвиться процесс с конечный
# тип частица ветвиться процесс с конечный число
# частица ветвиться процесс с конечный число тип
# линейный система дифференциальный уравнение с периодический коэффициент
# система дифференциальный уравнение с периодический коэффициент линейный
# дифференциальный уравнение с периодический коэффициент линейный система
# уравнение с периодический коэффициент линейный система дифференциальный
# с периодический коэффициент линейный система дифференциальный уравнение
# периодический коэффициент линейный система дифференциальный уравнение с
# коэффициент линейный система дифференциальный уравнение с периодический
# дифференциальный уравнение с малое параметр при производный
# уравнение с малое параметр при производный дифференциальный
# с малое параметр при производный дифференциальный уравнение
# малое параметр при производный дифференциальный уравнение с
# параметр при производный дифференциальный уравнение с малое
# при производный дифференциальный уравнение с малое параметр
# производный дифференциальный уравнение с малое параметр при
# линейный дифференциальный уравнение в банахов пространство
# дифференциальный уравнение в банахов пространство линейный
# уравнение в банахов пространство линейный дифференциальный
# в банахов пространство линейный дифференциальный уравнение
# банахов пространство линейный дифференциальный уравнение в
# пространство линейный дифференциальный уравнение в банахов
# линейный дифференциальный уравнение с постоянный коэффициент
# дифференциальный уравнение с постоянный коэффициент линейный
# уравнение с постоянный коэффициент линейный дифференциальный
# с постоянный коэффициент линейный дифференциальный уравнение
# постоянный коэффициент линейный дифференциальный уравнение с
# коэффициент линейный дифференциальный уравнение с постоянный
# случайный точечный процесс с ограниченный последействие
# точечный процесс с ограниченный последействие случайный
# процесс с ограниченный последействие случайный точечный
# с ограниченный последействие случайный точечный процесс
# ограниченный последействие случайный точечный процесс с
# последействие случайный точечный процесс с ограниченный
# код с исправление выпадение и вставка
# с исправление выпадение и вставка код
# исправление выпадение и вставка код с
# выпадение и вставка код с исправление
# и вставка код с исправление выпадение
# вставка код с исправление выпадение и
# ветвиться процесс с зависимость от возраст
# процесс с зависимость от возраст ветвиться
# с зависимость от возраст ветвиться процесс
# зависимость от возраст ветвиться процесс с
# от возраст ветвиться процесс с зависимость
# возраст ветвиться процесс с зависимость от
# главное тип оператор с частный производный
# тип оператор с частный производный главное
# оператор с частный производный главное тип
# с частный производный главное тип оператор
# частный производный главное тип оператор с
# производный главное тип оператор с частный
# высокий алгебраический степень точность квадратурный формула
# алгебраический степень точность квадратурный формула высокий
# степень точность квадратурный формула высокий алгебраический
# точность квадратурный формула высокий алгебраический степень
# квадратурный формула высокий алгебраический степень точность
# формула высокий алгебраический степень точность квадратурный
# интегрирование дифференциальный уравнение в замкнутый форма
# дифференциальный уравнение в замкнутый форма интегрирование
# уравнение в замкнутый форма интегрирование дифференциальный
# в замкнутый форма интегрирование дифференциальный уравнение
# замкнутый форма интегрирование дифференциальный уравнение в
# форма интегрирование дифференциальный уравнение в замкнутый
# код с исправление арифметический ошибка
# с исправление арифметический ошибка код
# исправление арифметический ошибка код с
# арифметический ошибка код с исправление
# ошибка код с исправление арифметический
# случайный процесс с стационарный приращение
# процесс с стационарный приращение случайный
# с стационарный приращение случайный процесс
# стационарный приращение случайный процесс с
# приращение случайный процесс с стационарный
# устойчивость при постоянно действовать возмущение
# при постоянно действовать возмущение устойчивость
# постоянно действовать возмущение устойчивость при
# действовать возмущение устойчивость при постоянно
# возмущение устойчивость при постоянно действовать
# дифференциальный уравнение с частный производный
# уравнение с частный производный дифференциальный
# с частный производный дифференциальный уравнение
# частный производный дифференциальный уравнение с
# производный дифференциальный уравнение с частный
# гильбертов пространство с индефинитный метрика
# пространство с индефинитный метрика гильбертов
# с индефинитный метрика гильбертов пространство
# индефинитный метрика гильбертов пространство с
# метрика гильбертов пространство с индефинитный
# дифференциальный уравнение в полный дифференциал
# уравнение в полный дифференциал дифференциальный
# в полный дифференциал дифференциальный уравнение
# полный дифференциал дифференциальный уравнение в
# дифференциал дифференциальный уравнение в полный
# дифференциальный уравнение с отклоняться аргумент
# уравнение с отклоняться аргумент дифференциальный
# с отклоняться аргумент дифференциальный уравнение
# отклоняться аргумент дифференциальный уравнение с
# аргумент дифференциальный уравнение с отклоняться
# аппроксимация дифференциальный краевой задача разностный
# дифференциальный краевой задача разностный аппроксимация
# краевой задача разностный аппроксимация дифференциальный
# задача разностный аппроксимация дифференциальный краевой
# разностный аппроксимация дифференциальный краевой задача
# граничный задача теория аналитический функция
# задача теория аналитический функция граничный
# теория аналитический функция граничный задача
# аналитический функция граничный задача теория
# функция граничный задача теория аналитический
# нелинейный уравнение с частный производный
# уравнение с частный производный нелинейный
# с частный производный нелинейный уравнение
# частный производный нелинейный уравнение с
# производный нелинейный уравнение с частный
# стандартизация и унификация математический задача
# и унификация математический задача стандартизация
# унификация математический задача стандартизация и
# математический задача стандартизация и унификация
# задача стандартизация и унификация математический
# линейный дифференциальный уравнение второй порядок
# дифференциальный уравнение второй порядок линейный
# уравнение второй порядок линейный дифференциальный
# второй порядок линейный дифференциальный уравнение
# порядок линейный дифференциальный уравнение второй
# случайный процесс с независимый приращение
# процесс с независимый приращение случайный
# с независимый приращение случайный процесс
# независимый приращение случайный процесс с
# приращение случайный процесс с независимый
# марков цепь нулевой класс состояние
# цепь нулевой класс состояние марков
# нулевой класс состояние марков цепь
# класс состояние марков цепь нулевой
# состояние марков цепь нулевой класс
# интегральный уравнение с симметричный ядро
# уравнение с симметричный ядро интегральный
# с симметричный ядро интегральный уравнение
# симметричный ядро интегральный уравнение с
# ядро интегральный уравнение с симметричный
# распределение степенной вычет и невычёт
# степенной вычет и невычёт распределение
# вычет и невычёт распределение степенной
# и невычёт распределение степенной вычет
# невычёт распределение степенной вычет и
# линейный параболический уравнение и система
# параболический уравнение и система линейный
# уравнение и система линейный параболический
# и система линейный параболический уравнение
# система линейный параболический уравнение и
# внешний и внутренний краевой задача
# и внутренний краевой задача внешний
# внутренний краевой задача внешний и
# краевой задача внешний и внутренний
# задача внешний и внутренний краевой
# игра с выбор момент временить
# с выбор момент временить игра
# выбор момент временить игра с
# момент временить игра с выбор
# временить игра с выбор момент
# смешанный произведение (a b с)
# произведение (a b с) смешанный
# (a b с) смешанный произведение
# b с) смешанный произведение (a
# с) смешанный произведение (a b
# канал с конечный число состояние
# с конечный число состояние канал
# конечный число состояние канал с
# число состояние канал с конечный
# состояние канал с конечный число
# узел и зацепление квадратичный форма
# и зацепление квадратичный форма узел
# зацепление квадратичный форма узел и
# квадратичный форма узел и зацепление
# форма узел и зацепление квадратичный
# дифференциальный уравнение с запаздывать аргумент
# уравнение с запаздывать аргумент дифференциальный
# с запаздывать аргумент дифференциальный уравнение
# запаздывать аргумент дифференциальный уравнение с
# аргумент дифференциальный уравнение с запаздывать
# классический небесный механика математический задача
# небесный механика математический задача классический
# механика математический задача классический небесный
# математический задача классический небесный механика
# задача классический небесный механика математический
# коммутационный и антикоммутационный соотношение представление
# и антикоммутационный соотношение представление коммутационный
# антикоммутационный соотношение представление коммутационный и
# соотношение представление коммутационный и антикоммутационный
# представление коммутационный и антикоммутационный соотношение
# марков цепь положительный класс состояние
# цепь положительный класс состояние марков
# положительный класс состояние марков цепь
# класс состояние марков цепь положительный
# состояние марков цепь положительный класс
# борель усиленный закон больший чисеть
# усиленный закон больший чисеть борель
# закон больший чисеть борель усиленный
# больший чисеть борель усиленный закон
# чисеть борель усиленный закон больший
# линейный эллиптический уравнение и система
# эллиптический уравнение и система линейный
# уравнение и система линейный эллиптический
# и система линейный эллиптический уравнение
# система линейный эллиптический уравнение и
# ветвиться процесс с случайный среда
# процесс с случайный среда ветвиться
# с случайный среда ветвиться процесс
# случайный среда ветвиться процесс с
# среда ветвиться процесс с случайный
# линейный гиперболический уравнение и система
# гиперболический уравнение и система линейный
# уравнение и система линейный гиперболический
# и система линейный гиперболический уравнение
# система линейный гиперболический уравнение и
# квазилинейный гиперболический уравнение и система
# гиперболический уравнение и система квазилинейный
# уравнение и система квазилинейный гиперболический
# и система квазилинейный гиперболический уравнение
# система квазилинейный гиперболический уравнение и
# группа с однозначный извлечение корень
# с однозначный извлечение корень группа
# однозначный извлечение корень группа с
# извлечение корень группа с однозначный
# корень группа с однозначный извлечение
# верхний и нижний функция метод
# и нижний функция метод верхний
# нижний функция метод верхний и
# функция метод верхний и нижний
# метод верхний и нижний функция
# наименее уклоняться от нуль многочлен
# уклоняться от нуль многочлен наименее
# от нуль многочлен наименее уклоняться
# нуль многочлен наименее уклоняться от
# многочлен наименее уклоняться от нуль
# линейный алгебраический группа арифметический теория
# алгебраический группа арифметический теория линейный
# группа арифметический теория линейный алгебраический
# арифметический теория линейный алгебраический группа
# теория линейный алгебраический группа арифметический
# абсолютно сходиться несобственный интеграл
# сходиться несобственный интеграл абсолютно
# несобственный интеграл абсолютно сходиться
# интеграл абсолютно сходиться несобственный
# алгебраический многочлен хороший приближение
# многочлен хороший приближение алгебраический
# хороший приближение алгебраический многочлен
# приближение алгебраический многочлен хороший
# безикович почти периодический функция
# почти периодический функция безикович
# периодический функция безикович почти
# функция безикович почти периодический
# релятивистский термодинамика математический задача
# термодинамика математический задача релятивистский
# математический задача релятивистский термодинамика
# задача релятивистский термодинамика математический
# динамический задача теория упругость
# задача теория упругость динамический
# теория упругость динамический задача
# упругость динамический задача теория
# диофантовый проблема аддитивный тип
# проблема аддитивный тип диофантовый
# аддитивный тип диофантовый проблема
# тип диофантовый проблема аддитивный
# ньютона- котёс квадратурный формула
# котёс квадратурный формула ньютона-
# квадратурный формула ньютона- котёс
# формула ньютона- котёс квадратурный
# продолжаемость решение дифференциальный уравнение
# решение дифференциальный уравнение продолжаемость
# дифференциальный уравнение продолжаемость решение
# уравнение продолжаемость решение дифференциальный
# приближение функция комплексный переменный
# функция комплексный переменный приближение
# комплексный переменный приближение функция
# переменный приближение функция комплексный
# валле пуссена многоточечный задача
# пуссена многоточечный задача валле
# многоточечный задача валле пуссена
# задача валле пуссена многоточечный
# двумерный многообразие ограниченный кривизна
# многообразие ограниченный кривизна двумерный
# ограниченный кривизна двумерный многообразие
# кривизна двумерный многообразие ограниченный
# вариация среднее значение теорема
# среднее значение теорема вариация
# значение теорема вариация среднее
# теорема вариация среднее значение
# тупиковый дизъюнктивный нормальный форма
# дизъюнктивный нормальный форма тупиковый
# нормальный форма тупиковый дизъюнктивный
# форма тупиковый дизъюнктивный нормальный
# галуа теория обратный задача
# теория обратный задача галуа
# обратный задача галуа теория
# задача галуа теория обратный
# плоский действительный алгебраический кривать
# действительный алгебраический кривать плоский
# алгебраический кривать плоский действительный
# кривать плоский действительный алгебраический
# код с исправление ошибка
# с исправление ошибка код
# исправление ошибка код с
# ошибка код с исправление
# интегральный представление аналитический функция
# представление аналитический функция интегральный
# аналитический функция интегральный представление
# функция интегральный представление аналитический
# алгебра с ассоциативный степень
# с ассоциативный степень алгебра
# ассоциативный степень алгебра с
# степень алгебра с ассоциативный
# параметрический резонанс математический теория
# резонанс математический теория параметрический
# математический теория параметрический резонанс
# теория параметрический резонанс математический
# группа с условие максимальность
# с условие максимальность группа
# условие максимальность группа с
# максимальность группа с условие
# ветвиться процесс с иммиграция
# процесс с иммиграция ветвиться
# с иммиграция ветвиться процесс
# иммиграция ветвиться процесс с
# максимальный и минимальный оператор
# и минимальный оператор максимальный
# минимальный оператор максимальный и
# оператор максимальный и минимальный
# почти приводить линейный система
# приводить линейный система почти
# линейный система почти приводить
# система почти приводить линейный
# главный часть дифференциальный оператор
# часть дифференциальный оператор главный
# дифференциальный оператор главный часть
# оператор главный часть дифференциальный
# нормальный фундаментальный система решение
# фундаментальный система решение нормальный
# система решение нормальный фундаментальный
# решение нормальный фундаментальный система
# максимум и минимум функция
# и минимум функция максимум
# минимум функция максимум и
# функция максимум и минимум
# максимум и минимум точка
# и минимум точка максимум
# минимум точка максимум и
# точка максимум и минимум
# статистический физика математический задача
# физика математический задача статистический
# математический задача статистический физика
# задача статистический физика математический
# газовый динамика численный метод
# динамика численный метод газовый
# численный метод газовый динамика
# метод газовый динамика численный
# продолжение по параметр метод
# по параметр метод продолжение
# параметр метод продолжение по
# метод продолжение по параметр
# собственный значение интегральный оператор
# значение интегральный оператор собственный
# интегральный оператор собственный значение
# оператор собственный значение интегральный
# ассоциативный кольцо и алгебра
# кольцо и алгебра ассоциативный
# и алгебра ассоциативный кольцо
# алгебра ассоциативный кольцо и
# линейный дифференциальный уравнение обыкновенный
# дифференциальный уравнение обыкновенный линейный
# уравнение обыкновенный линейный дифференциальный
# обыкновенный линейный дифференциальный уравнение
# ли алгебра аналитический группа
# алгебра аналитический группа ли
# аналитический группа ли алгебра
# группа ли алгебра аналитический
# ли алгебра алгебраический группа
# алгебра алгебраический группа ли
# алгебраический группа ли алгебра
# группа ли алгебра алгебраический
# бохнера почти периодический функция
# почти периодический функция бохнера
# периодический функция бохнера почти
# функция бохнера почти периодический
# степанов почти периодический функция
# почти периодический функция степанов
# периодический функция степанов почти
# функция степанов почти периодический
# вейль почти периодический функция
# почти периодический функция вейль
# периодический функция вейль почти
# функция вейль почти периодический
# бор почти периодический функция
# почти периодический функция бор
# периодический функция бор почти
# функция бор почти периодический
# ван дер варден критерий
# дер варден критерий ван
# варден критерий ван дер
# критерий ван дер варден
# равномерно наиболее мощный критерий
# наиболее мощный критерий равномерно
# мощный критерий равномерно наиболее
# критерий равномерно наиболее мощный
# параметрический интегральный представление метод
# интегральный представление метод параметрический
# представление метод параметрический интегральный
# метод параметрический интегральный представление
# локально линейно связный пространство
# линейно связный пространство локально
# связный пространство локально линейно
# пространство локально линейно связный
# релятивистский гидродинамика математический задача
# гидродинамика математический задача релятивистский
# математический задача релятивистский гидродинамика
# задача релятивистский гидродинамика математический
# релятивистский астрофизик математический задача
# астрофизик математический задача релятивистский
# математический задача релятивистский астрофизик
# задача релятивистский астрофизик математический
# хороший приближение в средний
# приближение в средний хороший
# в средний хороший приближение
# средний хороший приближение в
# риманов поверхность конформный класс
# поверхность конформный класс риманов
# конформный класс риманов поверхность
# класс риманов поверхность конформный
# гёделить теорема о неполнота
# теорема о неполнота гёделить
# о неполнота гёделить теорема
# неполнота гёделить теорема о
# сравнение от несколько переменный
# от несколько переменный сравнение
# несколько переменный сравнение от
# переменный сравнение от несколько
# сравнение по простой модуль
# по простой модуль сравнение
# простой модуль сравнение по
# модуль сравнение по простой
# нейман метод доверительный интервал
# метод доверительный интервал нейман
# доверительный интервал нейман метод
# интервал нейман метод доверительный
# ветвиться процесс с диффузия
# процесс с диффузия ветвиться
# с диффузия ветвиться процесс
# диффузия ветвиться процесс с
# александров-чех гомология и кого-мология
# гомология и кого-мология александров-чех
# и кого-мология александров-чех гомология
# кого-мология александров-чех гомология и
# оптимальный управление математический теория
# управление математический теория оптимальный
# математический теория оптимальный управление
# теория оптимальный управление математический
# двойной и дуальный число
# и дуальный число двойной
# дуальный число двойной и
# число двойной и дуальный
# больший число усиленный закон
# число усиленный закон больший
# усиленный закон больший число
# закон больший число усиленный
# спектральный оценка максимальный энтропия
# оценка максимальный энтропия спектральный
# максимальный энтропия спектральный оценка
# энтропия спектральный оценка максимальный
# ляпунов поверхность и кривыя
# поверхность и кривыя ляпунов
# и кривыя ляпунов поверхность
# кривыя ляпунов поверхность и
# диофантовый приближение метрический теория
# приближение метрический теория диофантовый
# метрический теория диофантовый приближение
# теория диофантовый приближение метрический
# конструктивный функция действительный переменный
# функция действительный переменный конструктивный
# действительный переменный конструктивный функция
# переменный конструктивный функция действительный
# верхний и нижний гранить
# и нижний гранить верхний
# нижний гранить верхний и
# гранить верхний и нижний
# игра на единичный квадрат
# на единичный квадрат игра
# единичный квадрат игра на
# квадрат игра на единичный
# канал с конечный память
# с конечный память канал
# конечный память канал с
# память канал с конечный
# ли вполне разрешимый алгебра
# вполне разрешимый алгебра ли
# разрешимый алгебра ли вполне
# алгебра ли вполне разрешимый
# представление с старший вектор
# с старший вектор представление
# старший вектор представление с
# вектор представление с старший
# длина и площадь принцип
# и площадь принцип длина
# площадь принцип длина и
# принцип длина и площадь
# обобщённый почти периодический функция
# почти периодический функция обобщённый
# периодический функция обобщённый почти
# функция обобщённый почти периодический
# пространство с индефинитный метрика
# с индефинитный метрика пространство
# индефинитный метрика пространство с
# метрика пространство с индефинитный
# магнитная гидродинамика математический задача
# гидродинамика математический задача магнитная
# математический задача магнитная гидродинамика
# задача магнитная гидродинамика математический
# непрерывный аналог итерационный метод
# аналог итерационный метод непрерывный
# итерационный метод непрерывный аналог
# метод непрерывный аналог итерационный
# декартов прямоугольный система координата
# прямоугольный система координата декартов
# система координата декартов прямоугольный
# координата декартов прямоугольный система
# нигде не плотный множество
# не плотный множество нигде
# плотный множество нигде не
# множество нигде не плотный
# канал с обратный связь
# с обратный связь канал
# обратный связь канал с
# связь канал с обратный
# изгибание на главный основание
# на главный основание изгибание
# главный основание изгибание на
# основание изгибание на главный
# картан метод внешний форма
# метод внешний форма картан
# внешний форма картан метод
# форма картан метод внешний
# альтернировать узел и зацепление
# узел и зацепление альтернировать
# и зацепление альтернировать узел
# зацепление альтернировать узел и
# узел и зацепление диаграмма
# и зацепление диаграмма узел
# зацепление диаграмма узел и
# диаграмма узел и зацепление
# узел и зацепление группа
# и зацепление группа узел
# зацепление группа узел и
# группа узел и зацепление
# альтернативный кольцо и алгебра
# кольцо и алгебра альтернативный
# и алгебра альтернативный кольцо
# алгебра альтернативный кольцо и
# конструктивный квантовый теория поль
# квантовый теория поль конструктивный
# теория поль конструктивный квантовый
# поль конструктивный квантовый теория
# стабильный и нестабильный теория
# и нестабильный теория стабильный
# нестабильный теория стабильный и
# теория стабильный и нестабильный
# надёжность и контроль управлять
# и контроль управлять надёжность
# контроль управлять надёжность и
# управлять надёжность и контроль
# локальный и резидуальный свойство
# и резидуальный свойство локальный
# резидуальный свойство локальный и
# свойство локальный и резидуальный
# логарифмически субга армонический функция
# субга армонический функция логарифмически
# армонический функция логарифмически субга
# функция логарифмически субга армонический
# аппроксимация дифференциальный уравнение разностный
# дифференциальный уравнение разностный аппроксимация
# уравнение разностный аппроксимация дифференциальный
# разностный аппроксимация дифференциальный уравнение
# булев функция метрический теория
# функция метрический теория булев
# метрический теория булев функция
# теория булев функция метрический
# включение и исключение принцип
# и исключение принцип включение
# исключение принцип включение и
# принцип включение и исключение
# максимизация и минимизация функция
# и минимизация функция максимизация
# минимизация функция максимизация и
# функция максимизация и минимизация
# булев функция нормальный форма
# функция нормальный форма булев
# нормальный форма булев функция
# форма булев функция нормальный
# потенциал теория обратный задача
# теория обратный задача потенциал
# обратный задача потенциал теория
# задача потенциал теория обратный
# глобально симметрический риманов пространство
# симметрический риманов пространство глобально
# риманов пространство глобально симметрический
# пространство глобально симметрический риманов
# риманов геометрия в целый
# геометрия в целый риманов
# в целый риманов геометрия
# целый риманов геометрия в
# необходимый и достаточный условие
# и достаточный условие необходимый
# достаточный условие необходимый и
# условие необходимый и достаточный
# верхний и нижний предел
# и нижний предел верхний
# нижний предел верхний и
# предел верхний и нижний
# неассоциативный кольцо и алгебра
# кольцо и алгебра неассоциативный
# и алгебра неассоциативный кольцо
# алгебра неассоциативный кольцо и
# вариационный исчисление в целый
# исчисление в целый вариационный
# в целый вариационный исчисление
# целый вариационный исчисление в
# сходимость в среднее порядкара
# в среднее порядкара сходимость
# среднее порядкара сходимость в
# порядкара сходимость в среднее
# ли вполне разрешимый группа
# вполне разрешимый группа ли
# разрешимый группа ли вполне
# группа ли вполне разрешимый
# гомология с компактный носитель
# с компактный носитель гомология
# компактный носитель гомология с
# носитель гомология с компактный
# однородный пространство алгебраический группа
# пространство алгебраический группа однородный
# алгебраический группа однородный пространство
# группа однородный пространство алгебраический
# статистический анализ случайный процесс
# анализ случайный процесс статистический
# случайный процесс статистический анализ
# процесс статистический анализ случайный
# звёздный астрономия математический задача
# астрономия математический задача звёздный
# математический задача звёздный астрономия
# задача звёздный астрономия математический
# линейный форма от логарифм
# форма от логарифм линейный
# от логарифм линейный форма
# логарифм линейный форма от
# ударный волна математический теория
# волна математический теория ударный
# математический теория ударный волна
# теория ударный волна математический
# рождение и гибель процесс
# и гибель процесс рождение
# гибель процесс рождение и
# процесс рождение и гибель
# рисовскай полугруппа матричный тип
# полугруппа матричный тип рисовскай
# матричный тип рисовскай полугруппа
# тип рисовскай полугруппа матричный
# дифференциал на римановой поверхность
# на римановой поверхность дифференциал
# римановой поверхность дифференциал на
# поверхность дифференциал на римановой
# ван дер поле уравнение
# дер поле уравнение ван
# поле уравнение ван дер
# уравнение ван дер поле
# вогнутый и выпуклый оператор
# и выпуклый оператор вогнутый
# выпуклый оператор вогнутый и
# оператор вогнутый и выпуклый
# схема из функциональный элемент
# из функциональный элемент схема
# функциональный элемент схема из
# элемент схема из функциональный
# относительно открытый (замкнутое) множество
# открытый (замкнутое) множество относительно
# (замкнутое) множество относительно открытый
# множество относительно открытый (замкнутое)
# диофантовый уравнение проблема разрешимость
# уравнение проблема разрешимость диофантовый
# проблема разрешимость диофантовый уравнение
# разрешимость диофантовый уравнение проблема
# граничный свойство аналитический функция
# свойство аналитический функция граничный
# аналитический функция граничный свойство
# функция граничный свойство аналитический
# китайский теорема о остаток
# теорема о остаток китайский
# о остаток китайский теорема
# остаток китайский теорема о
# вполне приводить матричный группа
# приводить матричный группа вполне
# матричный группа вполне приводить
# группа вполне приводить матричный
# контактный задача теория упругость
# задача теория упругость контактный
# теория упругость контактный задача
# упругость контактный задача теория
# верхний грань семейство топология
# грань семейство топология верхний
# семейство топология верхний грань
# топология верхний грань семейство
# устойчивость по часть переменный
# по часть переменный устойчивость
# часть переменный устойчивость по
# переменный устойчивость по часть
# больший гарантировать результат принцип
# гарантировать результат принцип больший
# результат принцип больший гарантировать
# принцип больший гарантировать результат
# кендалл коэффициент ранговый корреляция
# коэффициент ранговый корреляция кендалл
# ранговый корреляция кендалл коэффициент
# корреляция кендалл коэффициент ранговый
# спирмена коэффициент ранговый корреляция
# коэффициент ранговый корреляция спирмена
# ранговый корреляция спирмена коэффициент
# корреляция спирмена коэффициент ранговый
# конструктивный по гёделить множество
# по гёделить множество конструктивный
# гёделить множество конструктивный по
# множество конструктивный по гёделить
# дробный интегрирование и дифференцирование
# интегрирование и дифференцирование дробный
# и дифференцирование дробный интегрирование
# дифференцирование дробный интегрирование и
# вписать и описать фигура
# и описать фигура вписать
# описать фигура вписать и
# фигура вписать и описать
# линейно регулярный случайный процесс
# регулярный случайный процесс линейно
# случайный процесс линейно регулярный
# процесс линейно регулярный случайный
# вполне интегрировать дифференциальный уравнение
# интегрировать дифференциальный уравнение вполне
# дифференциальный уравнение вполне интегрировать
# уравнение вполне интегрировать дифференциальный
# сравнение по двойной модуль
# по двойной модуль сравнение
# двойной модуль сравнение по
# модуль сравнение по двойной
# безгранично делимое распределение разложение
# делимое распределение разложение безгранично
# распределение разложение безгранично делимое
# разложение безгранично делимое распределение
# случайный и псевдослучайный число
# и псевдослучайный число случайный
# псевдослучайный число случайный и
# число случайный и псевдослучайный
# статистический механика математический задача
# механика математический задача статистический
# математический задача статистический механика
# задача статистический механика математический
# интегральный уравнение тип свёртка
# уравнение тип свёртка интегральный
# тип свёртка интегральный уравнение
# свёртка интегральный уравнение тип
# собственный значение дифференциальный операторов;
# значение дифференциальный операторов; собственный
# дифференциальный операторов; собственный значение
# операторов; собственный значение дифференциальный
# максимальный и минимальный расширение
# и минимальный расширение максимальный
# минимальный расширение максимальный и
# расширение максимальный и минимальный
# гильберт теовие интегральный уравнение
# теовие интегральный уравнение гильберт
# интегральный уравнение гильберт теовие
# уравнение гильберт теовие интегральный
# дифференциальный уравнение на тор
# уравнение на тор дифференциальный
# на тор дифференциальный уравнение
# тор дифференциальный уравнение на
# гёделить теорема о полнота
# теорема о полнота гёделить
# о полнота гёделить теорема
# полнота гёделить теорема о
# функция комплексный переменный теория
# комплексный переменный теория функция
# переменный теория функция комплексный
# теория функция комплексный переменный
# игра с иерархический структура
# с иерархический структура игра
# иерархический структура игра с
# структура игра с иерархический
# продолжение и охват метод
# и охват метод продолжение
# охват метод продолжение и
# метод продолжение и охват
# овражный функция метод минимизация
# функция метод минимизация овражный
# метод минимизация овражный функция
# минимизация овражный функция метод
# односторонний и двусторонний поверхность
# и двусторонний поверхность односторонний
# двусторонний поверхность односторонний и
# поверхность односторонний и двусторонний
# вариационный принцип классический механик
# принцип классический механик вариационный
# классический механик вариационный принцип
# механик вариационный принцип классический
# голоморфный выпуклый комплексный пространство
# выпуклый комплексный пространство голоморфный
# комплексный пространство голоморфный выпуклый
# пространство голоморфный выпуклый комплексный
# контактный задача теория теплопроводность
# задача теория теплопроводность контактный
# теория теплопроводность контактный задача
# теплопроводность контактный задача теория
# основный тип алгебраический поверхность
# тип алгебраический поверхность основный
# алгебраический поверхность основный тип
# поверхность основный тип алгебраический
# валле пуссена сингулярный интеграл
# пуссена сингулярный интеграл валле
# сингулярный интеграл валле пуссена
# интеграл валле пуссена сингулярный
# конформный отображение граничный свойство
# отображение граничный свойство конформный
# граничный свойство конформный отображение
# свойство конформный отображение граничный
# качественный теория дифференциальный уравнение
# теория дифференциальный уравнение качественный
# дифференциальный уравнение качественный теория
# уравнение качественный теория дифференциальный
# энтропийный теория динамический система
# теория динамический система энтропийный
# динамический система энтропийный теория
# система энтропийный теория динамический
# равновеликий и равносоставить фигура
# и равносоставить фигура равновеликий
# равносоставить фигура равновеликий и
# фигура равновеликий и равносоставить
# формальный язык представимый машина
# язык представимый машина формальный
# представимый машина формальный язык
# машина формальный язык представимый
# диофантовый приближение проблема эффективизация
# приближение проблема эффективизация диофантовый
# проблема эффективизация диофантовый приближение
# эффективизация диофантовый приближение проблема
# функция действительный переменный теория
# действительный переменный теория функция
# переменный теория функция действительный
# теория функция действительный переменный
# линник дискретный эргодический метод
# дискретный эргодический метод линник
# эргодический метод линник дискретный
# метод линник дискретный эргодический
# аппроксимация дифференциальный оператор разностный
# дифференциальный оператор разностный аппроксимация
# оператор разностный аппроксимация дифференциальный
# разностный аппроксимация дифференциальный оператор
# дифференцирование в сила система
# в сила система дифференцирование
# сила система дифференцирование в
# система дифференцирование в сила
# группа с условие минимальность
# с условие минимальность группа
# условие минимальность группа с
# минимальность группа с условие
# метрический теория динамический система
# теория динамический система метрический
# динамический система метрический теория
# система метрический теория динамический
# сходимость с вероятность единица
# с вероятность единица сходимость
# вероятность единица сходимость с
# единица сходимость с вероятность
# распределение дробный доля многомерный
# дробный доля многомерный распределение
# доля многомерный распределение дробный
# многомерный распределение дробный доля
# зависеть от параметр интеграл
# от параметр интеграл зависеть
# параметр интеграл зависеть от
# интеграл зависеть от параметр
# смешанный процесс авторегрессия-скользящий средний
# процесс авторегрессия-скользящий средний смешанный
# авторегрессия-скользящий средний смешанный процесс
# средний смешанный процесс авторегрессия-скользящий
# средний арифметический метод суммирование
# арифметический метод суммирование средний
# метод суммирование средний арифметический
# суммирование средний арифметический метод
# центр и фокус проблема
# и фокус проблема центр
# фокус проблема центр и
# проблема центр и фокус
# полугруппа с условие конечность
# с условие конечность полугруппа
# условие конечность полугруппа с
# конечность полугруппа с условие
# аналитический теория дифференциальный уравнение
# теория дифференциальный уравнение аналитический
# дифференциальный уравнение аналитический теория
# уравнение аналитический теория дифференциальный
# логарифмический точка ветвление
# точка ветвление логарифмический
# ветвление логарифмический точка
# операторный неприводимый представление
# неприводимый представление операторный
# представление операторный неприводимый
# аддитивный проблема делитель
# проблема делитель аддитивный
# делитель аддитивный проблема
# конечный приращение формула
# приращение формула конечный
# формула конечный приращение
# хороший приближение последовательность
# приближение последовательность хороший
# последовательность хороший приближение
# вполне нормальный пространство
# нормальный пространство вполне
# пространство вполне нормальный
# приближение в средний
# в средний приближение
# средний приближение в
# финслеровый пространство обобщённый
# пространство обобщённый финслеровый
# обобщённый финслеровый пространство
# бессель интерполяционный формула
# интерполяционный формула бессель
# формула бессель интерполяционный
# риман дифференциальный уравнение
# дифференциальный уравнение риман
# уравнение риман дифференциальный
# равномерно сходиться ряд
# сходиться ряд равномерно
# ряд равномерно сходиться
# сопрячь линейный преобразование
# линейный преобразование сопрячь
# преобразование сопрячь линейный
# гармонический анализ абстрактный
# анализ абстрактный гармонический
# абстрактный гармонический анализ
# алгебраический система многообразие
# система многообразие алгебраический
# многообразие алгебраический система
# нагрузить интегральный уравнение
# интегральный уравнение нагрузить
# уравнение нагрузить интегральный
# галуа топологический группа
# топологический группа галуа
# группа галуа топологический
# постоянный кривизна пространство
# кривизна пространство постоянный
# пространство постоянный кривизна
# выпуклый множество пространство
# множество пространство выпуклый
# пространство выпуклый множество
# алгебраически замкнутый поль
# замкнутый поль алгебраически
# поль алгебраически замкнутый
# достаточный множество функционал
# множество функционал достаточный
# функционал достаточный множество
# второй краевой задача
# краевой задача второй
# задача второй краевой
# самосопряжённый дифференциальный уравнение
# дифференциальный уравнение самосопряжённый
# уравнение самосопряжённый дифференциальный
# скользящий среднее процесс
# среднее процесс скользящий
# процесс скользящий среднее
# относительно бикомпактный множество
# бикомпактный множество относительно
# множество относительно бикомпактный
# локально разрешимый алгебра
# разрешимый алгебра локально
# алгебра локально разрешимый
# гильберт система аксиома
# система аксиома гильберт
# аксиома гильберт система
# нётеровый интегральный уравнение
# интегральный уравнение нётеровый
# уравнение нётеровый интегральный
# положительно определённый функция
# определённый функция положительно
# функция положительно определённый
# непрерывный серия представление
# серия представление непрерывный
# представление непрерывный серия
# марков система функция
# система функция марков
# функция марков система
# полный накопление точка
# накопление точка полный
# точка полный накопление
# оптимальный управление позиционный
# управление позиционный оптимальный
# позиционный оптимальный управление
# структурно упорядочить группа
# упорядочить группа структурно
# группа структурно упорядочить
# формальный система эквивалентность
# система эквивалентность формальный
# эквивалентность формальный система
# типично вещественный функция
# вещественный функция типично
# функция типично вещественный
# гиперкомплексный переменный функция
# переменный функция гиперкомплексный
# функция гиперкомплексный переменный
# абстракция актуальный бесконечность
# актуальный бесконечность абстракция
# бесконечность абстракция актуальный
# частично рекурсивный оператор
# рекурсивный оператор частично
# оператор частично рекурсивный
# главное однородный пространство
# однородный пространство главное
# пространство главное однородный
# совместность метод суммирование
# метод суммирование совместность
# суммирование совместность метод
# гиперболический метрика принцип
# метрика принцип гиперболический
# принцип гиперболический метрика
# отделимый пополнение кольцо
# пополнение кольцо отделимый
# кольцо отделимый пополнение
# сильно непрерывный полугруппа
# непрерывный полугруппа сильно
# полугруппа сильно непрерывный
# достижимый граничный точка
# граничный точка достижимый
# точка достижимый граничный
# обобщённый теория когомология
# теория когомология обобщённый
# когомология обобщённый теория
# вырожденный гипергеометрический функция
# гипергеометрический функция вырожденный
# функция вырожденный гипергеометрический
# бернштейн интерполяционный процесс
# интерполяционный процесс бернштейн
# процесс бернштейн интерполяционный
# дискретный нормирование кольцо
# нормирование кольцо дискретный
# кольцо дискретный нормирование
# импликативный нормальный форма
# нормальный форма импликативный
# форма импликативный нормальный
# упругость математический теория
# математический теория упругость
# теория упругость математический
# двойной слой потенциал
# слой потенциал двойной
# потенциал двойной слой
# когомология банахов алгебра
# банахов алгебра когомология
# алгебра когомология банахов
# аналитический функция абстрактный
# функция абстрактный аналитический
# абстрактный аналитический функция
# вполне геодезический многообразие
# геодезический многообразие вполне
# многообразие вполне геодезический
# механический квадратура метод
# квадратура метод механический
# метод механический квадратура
# асимптотически устойчивый решение
# устойчивый решение асимптотически
# решение асимптотически устойчивый
# аналитический модель язык
# модель язык аналитический
# язык аналитический модель
# трансверсальный эллиптический оператор
# эллиптический оператор трансверсальный
# оператор трансверсальный эллиптический
# дирихло разрывный множитель
# разрывный множитель дирихло
# множитель дирихло разрывный
# кортевега-де фрис уравнение
# фрис уравнение кортевега-де
# уравнение кортевега-де фрис
# минимизация вычислительный работа
# вычислительный работа минимизация
# работа минимизация вычислительный
# веиерштрасса эллиптический функция
# эллиптический функция веиерштрасса
# функция веиерштрасса эллиптический
# кольцо с деление
# с деление кольцо
# деление кольцо с
# вырожденный эллиптический уравнение
# эллиптический уравнение вырожденный
# уравнение вырожденный эллиптический
# изопериметрический неравенство классический
# неравенство классический изопериметрический
# классический изопериметрический неравенство
# однопараметрический группа преобразование
# группа преобразование однопараметрический
# преобразование однопараметрический группа
# действительный алгебраический многообразие
# алгебраический многообразие действительный
# многообразие действительный алгебраический
# обратный тригонометрический функция
# тригонометрический функция обратный
# функция обратный тригонометрический
# дирихло вариационный задача
# вариационный задача дирихло
# задача дирихло вариационный
# максимальный компактный подгруппа
# компактный подгруппа максимальный
# подгруппа максимальный компактный
# вещественный аналитический пространство
# аналитический пространство вещественный
# пространство вещественный аналитический
# астрометрия математический задача
# математический задача астрометрия
# задача астрометрия математический
# жёсткий аналитический пространство
# аналитический пространство жёсткий
# пространство жёсткий аналитический
# судзук спорадический группа
# спорадический группа судзук
# группа судзук спорадический
# статистический решение теория
# решение теория статистический
# теория статистический решение
# аксиоматический теория множество
# теория множество аксиоматический
# множество аксиоматический теория
# массовый обслуживание теория
# обслуживание теория массовый
# теория массовый обслуживание
# представление ассоциативный алгебра
# ассоциативный алгебра представление
# алгебра представление ассоциативный
# зональный сферический функция
# сферический функция зональный
# функция зональный сферический
# спектральный оценка параметрический
# оценка параметрический спектральный
# параметрический спектральный оценка
# комплексный интегрирование метод
# интегрирование метод комплексный
# метод комплексный интегрирование
# устойчивость вычислительный процесс
# вычислительный процесс устойчивость
# процесс устойчивость вычислительный
# геодезия математический задача
# математический задача геодезия
# задача геодезия математический
# непрерывный функция пространство
# функция пространство непрерывный
# пространство непрерывный функция
# тёплицев форма индефинитный
# форма индефинитный тёплицев
# индефинитный тёплицев форма
# александров бикомпактный расширение
# бикомпактный расширение александров
# расширение александров бикомпактный
# положительный вариация функция
# вариация функция положительный
# функция положительный вариация
# рельеф аналитический функция
# аналитический функция рельеф
# функция рельеф аналитический
# исключить третий закон
# третий закон исключить
# закон исключить третий
# термодинамический предельный переход
# предельный переход термодинамический
# переход термодинамический предельный
# совершенный нормальный форма
# нормальный форма совершенный
# форма совершенный нормальный
# естественно упорядочить группоид
# упорядочить группоид естественно
# группоид естественно упорядочить
# зоммерфельд условие излучение
# условие излучение зоммерфельд
# излучение зоммерфельд условие
# бейесовский решающий функция
# решающий функция бейесовский
# функция бейесовский решающий
# финитный аппроксимировать группа
# аппроксимировать группа финитный
# группа финитный аппроксимировать
# ортогональный латинский квадрат
# латинский квадрат ортогональный
# квадрат ортогональный латинский
# броуновский движение процесс
# движение процесс броуновский
# процесс броуновский движение
# океанология математический задача
# математический задача океанология
# задача океанология математический
# фазовый интеграл метод
# интеграл метод фазовый
# метод фазовый интеграл
# регулярный метод суммирование
# метод суммирование регулярный
# суммирование регулярный метод
# хороший приближение элемент
# приближение элемент хороший
# элемент хороший приближение
# мультипликативный арифметический функция
# арифметический функция мультипликативный
# функция мультипликативный арифметический
# вороной метод суммирование
# метод суммирование вороной
# суммирование вороной метод
# линейный краевой задача
# краевой задача линейный
# задача линейный краевой
# распределение значение теория
# значение теория распределение
# теория распределение значение
# второй квадратичный форма
# квадратичный форма второй
# форма второй квадратичный
# первый квадратичный форма
# квадратичный форма первый
# форма первый квадратичный
# квадратичный форма поверхность
# форма поверхность квадратичный
# поверхность квадратичный форма
# распределение простой чисеть
# ...
# эндоморфизм полупростой
# параболический точка
# точка параболический
# полукубический парабола
# парабола полукубический
# зигмунд класс
# класс зигмунд
# эрмитовый матрица
# матрица эрмитовый
# штурм теорема
# теорема штурм
# джексон неравенство
# неравенство джексон
# обобщённый производный
# производный обобщённый
# абсолютный непрерывность
# непрерывность абсолютный
# липшица условие
# условие липшица
# финслеров метрика
# метрика финслеров
# сильный дифференцирование
# дифференцирование сильный
# разрешимый множество
# множество разрешимый
# квадратический иррациональность
# иррациональность квадратический
# алгебраический иррациональность
# иррациональность алгебраический
# прекращение точка
# точка прекращение
# никольский пространство
# пространство никольский
# линделёф пространство
# пространство линделёф
# полный мера
# мера полный
# диагональный группа
# группа диагональный
# дифференциальный группа
# группа дифференциальный
# матричный группа
# группа матричный
# мономиальный матрица
# матрица мономиальный
# мономиальной представление
# представление мономиальной
# вербальный произведение
# произведение вербальный
# мультипликатор группа
# группа мультипликатор
# шрейер система
# система шрейер
# топологический эквивалентность
# эквивалентность топологический
# присоединить группа
# группа присоединить
# шмидт группа
# группа шмидт
# p-отделимый группа
# группа p-отделимый
# холлов подгруппа
# подгруппа холлов
# p-разрешимый группа
# группа p-разрешимый
# унимодулярный преобразование
# преобразование унимодулярный
# характеристический подгруппа
# подгруппа характеристический
# нильпотентный алгебра
# алгебра нильпотентный
# силон подгруппа
# подгруппа силон
# силовый теорема
# теорема силовый
# разрешимый группа
# группа разрешимый
# метабелево группа
# группа метабелево
# мальцевский произведение
# произведение мальцевский
# неразложимый континуум
# континуум неразложимый
# неатомический мера
# мера неатомический
# последовательность категория
# категория последовательность
# симплициальный объект
# объект симплициальный
# стандартный симплекс
# симплекс стандартный
# ультрабочечный пространство
# пространство ультрабочечный
# сопрячь пространство
# пространство сопрячь
# неприводимый континуум
# континуум неприводимый
# аналитический представление
# представление аналитический
# симметричный представление
# представление симметричный
# дюбуа-реймона теорёма
# теорёма дюбуа-реймона
# дирихло ядро
# ядро дирихло
# изотермический координата
# координата изотермический
# линейный представление
# представление линейный
# сохоцкий теорема
# теорема сохоцкий
# эрмит уравнение
# уравнение эрмит
# якоби уравнение
# уравнение якоби
# якоби символ
# символ якоби
# якоби принцип
# принцип якоби
# эрмит тождество
# тождество эрмит
# эйлеров число
# число эйлеров
# эрланг распределение
# распределение эрланг
# якоби многообразие
# многообразие якоби
# этальный топология
# топология этальный
# эрмитовый форма
# форма эрмитовый
# эрмитовый структура
# структура эрмитовый
# энергетический неравенство
# неравенство энергетический
# эмпирический распределение
# распределение эмпирический
# эллиптический параболоид
# параболоид эллиптический
# эллиптический точка
# точка эллиптический
# экстремаль семейство
# семейство экстремаль
# эллиптический кривать
# кривать эллиптический
# эйлеров интеграл
# интеграл эйлеров
# эйлеров углый
# углый эйлеров
# эйлер функция
# функция эйлер
# дифференцировать вектор
# вектор дифференцировать
# эйлер формула
# формула эйлер
# симплициальный схема
# схема симплициальный
# аналитический поверхность
# поверхность аналитический
# аналитический вектор
# вектор аналитический
# эйлер теорема
# теорема эйлер
# эйлер произведение
# произведение эйлер
# штурм-лиувилля задача
# задача штурм-лиувилля
# штейнера кривать
# кривать штейнера
# шрёдингер представление
# представление шрёдингер
# чебышевский альтернанс
# альтернанс чебышевский
# шнирельман метод
# метод шнирельман
# шварц формула
# формула шварц
# чебышевский точка
# точка чебышевский
# шварц уравнение
# уравнение шварц
# чебышёв функция
# функция чебышёв
# шаудёр метод
# метод шаудёр
# целочисленный программирование
# программирование целочисленный
# чебышёв теорема
# теорема чебышёв
# хаар мера
# мера хаар
# фубиня теорема
# теорема фубиня
# ходжа теорема
# теорема ходжа
# хинчин теорема
# теорема хинчин
# харди теорема
# теорема харди
# чебышёв теорема
# теорема чебышёв
# чебышёв неравенство
# неравенство чебышёв
# число теория
# теория число
# харди-литлвуда признак
# признак харди-литлвуда
# чезаро кривать
# кривать чезаро
# чева теорема
# теорема чева
# чебышёв метод
# метод чебышёв
# частный кольцо
# кольцо частный
# цорный лемма
# лемма цорный
# циклический координата
# координата циклический
# центральный ряд
# ряд центральный
# фреш поверхность
# поверхность фреш
# характеристика метод
# метод характеристика
# хан-банах теорема
# теорема хан-банах
# френ формула
# формула френ
# фраттиня подгруппа
# подгруппа фраттиня
# фарей ряд
# ряд фарей
# ферма спираль
# спираль ферма
# поглощение закон
# закон поглощение
# условный сходимость
# сходимость условный
# уровень множество
# множество уровень
# уравновесить множество
# множество уравновесить
# упорядочить сумма
# сумма упорядочить
# тетрациклический координата
# координата тетрациклический
# унитарный оператор
# оператор унитарный
# унитарный преобразование
# преобразование унитарный
# сферический функция
# функция сферический
# суслина гипотеза
# гипотеза суслина
# стинрод двойственность
# двойственность стинрод
# спектр кольцо
# кольцо спектр
# унитарный группа
# группа унитарный
# стилтьеса преобразование
# преобразование стилтьеса
# стеклов функция
# функция стеклов
# унипотентный группа
# группа унипотентный
# совершенный число
# число совершенный
# совершенный поль
# поль совершенный
# треугольный матрица
# матрица треугольный
# трансцендентность мера
# мера трансцендентность
# рациональный число
# число рациональный
# стеклов проблема
# проблема стеклов
# преобразование полугруппа
# полугруппа преобразование
# статистический оценивание
# оценивание статистический
# серра подкатегория
# подкатегория серра
# свободный модуль
# модуль свободный
# радикальный осить
# осить радикальный
# спуск метод
# метод спуск
# скрестить произведение
# произведение скрестить
# сверхразрешимый группа
# группа сверхразрешимый
# симплектический группа
# группа симплектический
# рефлективный подкатегория
# подкатегория рефлективный
# релятивный геометрия
# геометрия релятивный
# рекурсивный отношение
# отношение рекурсивный
# регрессия поверхность
# поверхность регрессия
# преследование игра
# игра преследование
# распределение функция
# функция распределение
# рамануджан гипотеза
# гипотеза рамануджан
# разрешимый многообразие
# многообразие разрешимый
# полиномиальный коэффициент
# коэффициент полиномиальный
# квадратичный отклонение
# отклонение квадратичный
# плотность последовательность
# последовательность плотность
# параболический цилиндр
# цилиндр параболический
# отсчёт система
# система отсчёт
# осциллятор гармонический
# гармонический осциллятор
# линейный функционал
# функционал линейный
# икосаэдр пространство
# пространство икосаэдр
# билинейный отображение
# отображение билинейный
# ортогональный группа
# группа ортогональный
# двойной последовательность
# последовательность двойной
# нормальный уравнение
# уравнение нормальный
# нормальный плоскость
# плоскость нормальный
# данжуа интеграл
# интеграл данжуа
# непредикативный определение
# определение непредикативный
# гильберт-шмидт норма
# норма гильберт-шмидт
# менелай теорема
# теорема менелай
# линейный уравнение
# уравнение линейный
# лебег интеграл
# интеграл лебег
# лёвенхейм-сколема теорема
# теорема лёвенхейм-сколема
# векторный исчисление
# исчисление векторный
# компактный оператор
# оператор компактный
# кватернион группа
# группа кватернион
# квадратичный вычет
# вычет квадратичный
# область
# субдифференциал
# строфоида
# гипоциклоида
# кондуктор
# поток
# алеф-нуль
# график
# квантор
# перемешивание
# якобиан
# подкатегория
# биссектриса
# нуль-система
# лисп
# астроида
# доказательство
# апофема
# пирамида
# призматоид
# призма
# параллелепипед
# четырехвершинник
# минимум
# нормаль
# касательная
# бинормаль
# атом
# экстремум
# бином
# источник
# экстремаль
# ребро
# нильпоток
# градиент
# суммирование
# нильмногообразие
# дополнение
# структура
# аффинитет
# перпендикуляр
# отрезок
# промежуток
# группа
# абсцисса
# верзора
# катет
# гипотенуза
# наклонный
# полупрямой
# аппликата
# ордината
# тета-ряд
# модель
# размах
# период
# делимость
# гиперплоскость
# бифунктор
# упаковка
# код
# k-пространство
# оператор
# кортеж
# декодирование
# кривая
# функтор
# комплекс
# гиперграф
# непротиворечивость
# длина
# порядок
# дзета-функция
# потенциал
# факторизация
# средний
# решётка
# ортоцентр
# каскад
# вихрь
# дифференциал
# число
# нумерация
# последовательность
# автокорредограмма
# денотат
# нуль
# регулятор
# коалгебра
# вероятность
# мощность
# полурешётка
# орбита
# ряд
# морфизм
# объект
# связность
# отображение
# схема
# определитель
# матрица
# граф
# подмодуль
# локализация
# девиатор
# сюръекция
# цоколь
# отношение
# биекция
# инъекция
# неравенство
# индекс
# функционал
# квазигруппа
# фильтр
# ультрафильтр
# вычет
# группоид
# сравнение
# объём
# площадь
# семимартингал
# бесконечность
# дефект
# интуиционизм
# изотопия
# дивизор
# метатеорема
# метаязык
# верификация
# инцидентность
# окрестность
# нить
# интеграл
# теория
# сепаратриса
# статистика
# седло
# узел
# центро-фокус
# седло-узел
# грань
# икосаэдр
# уравнение
# квазимногообразие
# октаэдр
# квазитождество
# додекаэдр
# денумерант
# кольцо
# супергруппа
# деформация
# супермногообразие
# поле
# эпиморфизм
# общезначимость
# предпучок
# биморфизм
# корень
# инверсия
# перестановка
# осреднение
# компакт
# компактность
# трансвекция
# квадрат
# циклоида
# трохоида
# факториал
# рулетта
# полнота
# размерность
# кривизна
# континуум
# антидвижение
# функция
# радиус
# проекция
# орт
# пространство
# плоскость
# прямой
# действие
# коммутатор
# доминанта
# бикомпакт
# псевдогруппа
# радикал
# иррегулярность
# симплекс
# гамма-распределение
# аргумент
# аффикс
# разрез
# бикомпактификация
# сжатие
# сдвиг
# единица
# кватернион
# фигура
# альтернион
# множество
# базис
# изоль
# ковариация
# линия
# подобие
# конгруэнц-подгруппа
# гомотетия
# вектор
# рандомизация
# величина
# конгруэнтность
# стратификация
# сплайн-интерполяция
# риск
# мера
# сложение
# диагональ
# поверхность
# симметризация
# сфера
# связка
# пучок
# бицилиндрик
# умножение
# подгруппа
# круг
# копредставление
# трактриса
# лемниската
# гониометрия
# кардиоида
# касп
# гомеоморфизм
# антипод
# автоморфизм
# инволюция
# демиквадрика
# размещение
# подмногообразие
# слоение
# блок-схема
# субмерсия
# пульверизация
# сочетание
# многочлен
# высота
# бимодуль
# эквивалентность
# направление
# централизатор
# идеал
# форма
# медианта
# гессиан
# теорема
# нормирование
# неразрешимость
# класс
# несовместимость
# диаграмма
# момент
# квартиль
# композиция
# аппроксимация
# сигнатура
# перцентиль
# квантиль
# идель
# адель
# веер
# бар-индукция
# интерпретация
# вид
# толерантность
# сплетение
# максимин
# кручение
# итерация
# дуэль
# ассоциатор
# синусоида
# тангенсоида
# коэффициент
# дизъюнкция
# импликация
# конъюнкция
# гомоморфизм
# эндоморфизм
# полуплоскость
# полоса
# матрицант
# изоморфизм
# гармоника
# цепь
# парабола
# минор
# вронскиан
# гиперповерхность
# степень
# гипербола
# дихотомия
# приближение
# экстраполирование
# интерполирование
# непрерывность
# гравитация
# категория
# особенность
# след
# факторкатегория
# преобразование
# многообразие
# топос
# кобордизм
# характер
# квазихарактер
# бифуркация
# пересечение
# покрытие
# автомат
# резольвента
# предпорядок
# карта
# объединение
# поливектор
# когомология
# алгебра
# аксиома
# независимость
# корреляция
# регрессия
# росток
# контраст
# метрика
# мультиалгебра
# двоеточие
# производный
# масса
# подера
# статика
# динамика
# интервал
# полиэдр
# триангуляция
# пфаффиан
# нильполугруппа
# калибр
# процедура
# коммутативность
# омега-непротиворечивость
# омега-полнота
# гомоскедастичность
# константа
# рефал
# соединение
# локсодрома
# норма
# погружение
# регуляризация
# пи
# ассоциативность
# дистрибутивность
# координата
# движение
# вращение
# информация
# дискриминант
# супералгебра
# асимптота
# нормализатор
# нерв
# отражение
# соответствие
# грамматика
# окружность
# уклонение
# модуль
# дисперсия
# перспектива
# инвариант
# абсолют
# фактор
# алгол-68
# пл/i
# снобол
# вхождение
# алгол
# игрок
# стратегия
# коалиция
# полугруппа
# топология
# шар
# цилиндр
# конус
# сектор
# препятствие
# n-группа
# траектория
# запятая
# округление
# изогений
# стереоэдр
# планигон
# тело
# трансгрессия
# перенормировка
# база
# куб
# многоугольник
# лагранжиан
# конгруэнция
# невязка
# многогранник
# кубик
# коник
# квадрика
# реализуемость
# арифметика
# котангенс
# тензор
# пополнение
# аффинор
# вектор-функция
# тангенс
# эллипсоид
# сходимость
# секанс
# косеканс
# гиперболоид
# подразделение
# математик
# геометрия
# касание
# циссоида
# изгибание
# жёсткость
# желoб
# исчисление
# сечение
# угол
# ориентация
# огибать
# параллелотоп
# циркуляция
# тета-функция
# прямоугольник
# параллелограмм
# антипараллелограмм
# спинор
# испытание
# арифметизация
# сплайн-аппроксимация
# коразмерность
# край
# трансверсальность
# симметрия
# гомология
# двойственность
# почтикольцо
# пpo-p-группа
# аннулятор
# краткий
# тройка
# автоколебание
# спин
# резонанс
# информант
# радикал
# моноид
# имя
# гамма-функция
# комитант
# ковариант
# предсказуемый
# опциональный
# семиинвариант
# алгоритм
# программа
# изоклина
# кохлеоид
# коцепь
# отрицание
# совпадение
# заряд
# жезл
# дифференцирование
# вычет-форма
# квазирешение
# тест
# помехоустойчивость
# коннекс
# конфигурация
# сплайн
# кибернетика
# выпуклость
# биркгоф-виттатеорем
# термы
# логарифм
# дискрепанс
# вкб-метод
# числитель
# знаменатель
# делитель
# деление
# бордизм
# погрешность
# континуум-гипотеза
# коноид
# алеф
# мартингал
# полумартингал
# выборка
# ромб
# металогика
# квадрант
# октант
# распределение
# синтаксис
# семантика
# суждение
# бикатегория
# микрорасслоение
# симула
# машина
# вывод
# квадратриса
# тривектор
# бивектор
# вейерштрасса
# дублет
# аддитивность
# флаг
# волна
# логицизм
# конормаль
# дельта-функция
# логистика
# ячейка
# антиномия
# антипризма
# дуга
# клин
# стабилизатор
# ортогонализация
# ёмкость
# комбинаторика
# алгамс
# альфа
# накрытие
# подрешётка
# полукольцо
# обложение
# рекурсия
# разбиение
# синус
# косинус
# дробь
# поликруг
# симметрирование
# альтернирование
# делёж
# надстройка
# униформизация
# счисление
# минимакс
# псевдонормирование
# орисфера
# орицикл
# треугольник
# цифра
# пермутатор
# хорда
# матроида
# самопериметр
# модификация
# дерево
# медиана
# нарост
# камера
# метатеория
# мода
# l-родиться
# кактоид
# дендрит
# близнец
# суперпространство
# перегородка
# антье
# вычитание
# достоверность
# финитизм
# формализм
# коммутант
# вариация
# буква
# алфавит
# двуугольник
# поляра
# программирование
# псевдометрика
# результант
# пояс
# коррелограмма
# авторегрессия
# развёртка
# иерархия
# гиперпространство
# радиус-вектор
# геометродинамика
# плотность
# квадратура
# композит
# кобол
# амальгама
# диффеоморфизм
# квадрируемость
# оперение
# псевдотензор
# вертор
# полунорма
# псевдомногообразие
# диаметр
# овоид
# шапка
# вурф
# дециль
# эконометрия
# каустик
# невычет
# секунда
# градус
# минута
# p-группа
# ортогональность
# гамма-корреляция
# избыточность
# предикат
# порция
# первообразный
# скаляр
# аксонометрия
# полуинвариант
# чёрча-абстракция
# c2-распределение
# периметр
# полином
# турнир
# катеноид
# псевдосфера
# усреднение
# контингенция
# факторобъект
# солитон
# бихарактеристика
# s-двойственность
# тригонометрия
# струя
# гомотопия
# номография
# дилатация
# поперечник
# триада
# лупа
# идемпотент
# соприкосновение
# зоноэдр
# параллелоэдр
# кернфункция
# измельчение
# кратное
# адсорбция
# подматрица
# диада
# перестройка
# модальность
# l-функция
# сигнум
# предикативность
# коцикл
# солвмногообразие
# пространство-время
# сизигия
# роза
# полигон
# брахистохрона
# подобъект
# генератриса
# геликоид
# преднорма
# эквидистант
# периодограмма
# гиперцентр
# top
# овал
# операнд
# мультипликатор
# доминирование
# парадокс
# абак
# эвольвента
# нильгруппа
# кольцоид
# f-распределение
# z-распределение
# t-распределение
# прогрессия
# квазилинеаризация
# одночлен
# битый
# торс
# трапеция
# моносплайн
# дивергенция
# разность
# различать
# гистограмма
# симметрика
# альтернатива
# радиан
# стерадиан
# г-распределение
# фортран
# псевдодуга
# равносильность
# перманент
# веиерштрасса
# предмера
# гексаэдр
# годограф
# конхоида
# спаривание
# параболоид
# миноранта
# курант
# кобазис
# выводимость
# цилиндроид
# антонимия
# псевдоскаляр
# гамильтониан
# кумулянт
# бицилиндр
# луч
# ротор
# клеточноеотображение
# окатывание
# t2-распределение
# антилогарифм
# барьер
# мультиграф
# гиперцикл
# бикомплекс
# метаматематика
# w-распределение
# пси-функция
# w2-распределение
# в-распределение
# клотоида
# близость
# полюс
# g-расслоение
# расслоение
# ретракт
# решение
# репер
# секвенция
# антиизоморфизм
# рефлектор
# расширение
# эргодичность
# интегрирование
# псевдовектор
# детерминант
# интерполяция
# иммерсия
# ретракция
# уплотнение
# проектор
# сверхсходимость
# корасслоение
# h-пространство
# псевдобаза
# предел
# псевдохарактер
# цикл
# компонент
# ядро
# центр
# факторпредставление
# вес
# петлить
# путь
# клон
# квазинорма
# диск
# ко-н-пространство
# джет
# джойна
# коллинеация
# поляритет
# коядро
# противоречие
# надграфик
# предложение
# формула
# бикомпактность
# предбаза
# произведение
# спектр
# направленность
# характеристика
# лакуна
# ранг
# свёртка
# автоковариация
# автокорреляция
# ареа-функция
# аркфункция
# директриса
# фокус
# реплика
# трансляция
# каппа
# граница
# эксцентриситет
# симметричность
# сегмент
# экспонент
# рефлексивность
# транзитивность
# копроизведение
# нильалгебра
# эпициклоида
# энтропия
# эллипс
# эволюта
# факторгруппа
# факторпространство
# факторкольцо
# устойчивость
# тавтология
# спираль
# сеть
# тетраэдр
# подстановка
# мономорфизм
# конгруэнц-проблема

# %%
item = 'кыр сосичка чаво каво'
mixed_item = []
mixed_item.append(item)
d = item.find(" ")
c = item.count(' ')
while c > 0:
    item = item[d+1:] + ' ' + item[:d]
    d = item.find(" ")
    mixed_item.append(item)
    c = c - 1
for i in mixed_item:
    print i
# Out:
# кыр сосичка чаво каво
# сосичка чаво каво кыр
# чаво каво кыр сосичка
# каво кыр сосичка чаво

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
word = unicode('стали', 'utf-8')
for punkt in morph.parse(word):
    print punkt
# Out:
# Parse(word=u'\u0441\u0442\u0430\u043b\u0438', tag=OpencorporaTag('VERB,perf,intr plur,past,indc'), normal_form=u'\u0441\u0442\u0430\u0442\u044c', score=0.975342, methods_stack=((DictionaryAnalyzer(), u'\u0441\u0442\u0430\u043b\u0438', 945, 4),))
# Parse(word=u'\u0441\u0442\u0430\u043b\u0438', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form=u'\u0441\u0442\u0430\u043b\u044c', score=0.010958, methods_stack=((DictionaryAnalyzer(), u'\u0441\u0442\u0430\u043b\u0438', 13, 1),))
# Parse(word=u'\u0441\u0442\u0430\u043b\u0438', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form=u'\u0441\u0442\u0430\u043b\u044c', score=0.005479, methods_stack=((DictionaryAnalyzer(), u'\u0441\u0442\u0430\u043b\u0438', 13, 6),))
# Parse(word=u'\u0441\u0442\u0430\u043b\u0438', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form=u'\u0441\u0442\u0430\u043b\u044c', score=0.002739, methods_stack=((DictionaryAnalyzer(), u'\u0441\u0442\u0430\u043b\u0438', 13, 2),))
# Parse(word=u'\u0441\u0442\u0430\u043b\u0438', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form=u'\u0441\u0442\u0430\u043b\u044c', score=0.002739, methods_stack=((DictionaryAnalyzer(), u'\u0441\u0442\u0430\u043b\u0438', 13, 5),))
# Parse(word=u'\u0441\u0442\u0430\u043b\u0438', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form=u'\u0441\u0442\u0430\u043b\u044c', score=0.002739, methods_stack=((DictionaryAnalyzer(), u'\u0441\u0442\u0430\u043b\u0438', 13, 9),))

# %%
norm_library.sort(key=lambda x: 0 - x.count(" "))

# %%
#Попытка собрать воедино

# %%
import os
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# set max amount of files (compare with af)
# -1 equal infinity
max_files = 2

# Open and clean tex doc
def next_tex_doc(address):
    doc = "" # returning value, string
    texdoc = []  # a list of string representing the latex document in python
    # read the .tex file, and modify the lines
    with open(address, 'UTF-8') as texdoc:
        for line in texdoc:
            #######
            #line = 'н унитарный оператор оператор сопряженный интеграл интеграл интеграл элементарная система аксиома в'
            l = unicode(line, 'utf-8')
            if l.find('%') != 0:
                if len(l) > 0:
                    #l = l.lower().replace("~---", "")
                    #don't want to change amount of characters
                    l = l.replace(".~", ". ")
                    l = l.replace("{", ' ').replace("}", ' ')
                    l = l.replace("(", ' ').replace(")", ' ')
                    l = l.replace("[", ' ').replace("]", ' ')
                    l = l.replace("<", ' ').replace(">", ' ')
                    l = l.replace(".", ' ')
                    l = l.replace(",", ' ')
                    l = l.replace("!", ' ')
                    l = l.replace("?", ' ')
                    l = l.replace(";", ' ').replace(":", ' ')
                    doc = doc + l.replace("\n", " ")
    doc = doc + ' '
    return doc

# Print results for one term into out_file
def print_item(item, start, end, text):
    print '\t<item>'
    print '\t\t<term>' + item[2] + '</term>'
    print '\t\t<link>http://libmeta.ru/concept/show/' + item[1] + '</link>'
    print '\t\t<link>http://libmeta.ru/concept/' + item[1] + '</link>'
    print '\t\t<startpos>' + str(start) + '</startpos>'
    print '\t\t<endpos>' + str(end - 1) + '</endpos>'
    print '\t\t<linktext>' + text + '<linktext>'
    print '\t</item>'

# MAIN

# Open out_file
out_file = open('out.txt', 'r')

# Processing of dictionaries
libmeta = []  # a list of string representing the libmeta.txt
norm_library = [] # list of keywords in normal form
                  # with different word order for multi-word terms
                  # order by amount of words
with open('libmeta.txt', 'UTF-8') as libmeta:
    line_type = 0
    for line in libmeta:
        if line_type == 1: # this string contain link with 'show'
            line_type = 0
            link_num = line[41:-12]
            nitem = nitem.normal_form
            c = nitem.count(" ")
            if c == 0:
                norm_library.append([nitem, link_num, item])
            else:
                n_lst = nitem.split()
                nitem = ""
                for word in n_lst:
                    w = morph.parse(word)[0]
                    nitem = nitem + ' ' + w.normal_form
                nitem = nitem[1:]
                norm_library.append([nitem, link_num, item])
            while c > 0:
                d = nitem.find(" ")
                nitem = nitem[d+1:] + ' ' + nitem[:d]
                norm_library.append([nitem, link_num, item])
                c = c - 1
        elif (line.find("<lbm:Concept rdf:about") == 0) and (line[-2] == '>'):
            line_type = 1 # this string contain term
            y = line.find("#")
            keyword = unicode(line[y+1:-3], 'utf-8')
            x = x + 1
            if len(keyword) > 0:
                item = keyword.replace("_", " ").replace(" - ", "-").lower()
                nitem = morph.parse(item)[0]
norm_library.sort(key=lambda x: 0 - x[0].count(" "))

# Open files by rotation
print '<?xml version="1.0" encoding="utf-8"?>'
af = 0
tree = os.walk('all_TEX') # create tree of processed file names
for text in tree:
    for j in text[2]: # iteration over processed files
        af = af + 1
        # text[0] == 'all_TEX' == name of processed folder
        # j == name of processed file
        print '<file name:"' + text[0] + '/' + j + '">'
        doc = next_tex_doc(text[0] + '/' + j)
        num = 0
        lst = doc.encode('utf-8').split() # list of words from doc
        lst_num = [] # contain position for words from lst
        norm_lst = [] # future list of words from doc in normal form
        norm_lst_num = [] # contain position for words from norm_lst
        for word in lst: # create norm_lst and norm_lst_num
            w = morph.parse(word.decode('utf-8'))[0]
            norm_lst.append(w.normal_form)
            norm_lst_num.append(num)
            num = num + len(w.normal_form) + 1
        norm_doc = " ".join(norm_lst)
        num = -1
        check = [] # list which store scope of link text
                   # is used for checking conflicts
                   # like link 'word_1' into link 'word_1 word_2'
        for item in lst: # create lst_num
            num = num + 1 + doc[num + 1 :].find(item.decode('utf-8'))
            lst_num.append(num)
        #print lst_num
        #print norm_lst_num
        for item in norm_library:
            num = norm_doc.find(' ' + item[0] + ' ')
            last_num = -2
            a = 0
            while num > -1:
                #print 'NUM ' + str(num)
                if num == last_num:
                    break
                a = norm_lst_num.index(num + 1)
                #print 'A ' + str(a)
                nwords = item[0].count(" ") + 1
                end_link = lst_num[a + 1] - 1
                i = 0
                while nwords > 0:
                    end_link = lst_num[a + i + 1]
                    nwords = nwords - 1
                    i = i + 1
                while doc[lst_num[a] : end_link].count(" ") > item[0].count(" "):
                    end_link = end_link - 1
                if end_link < lst_num[a]:
                    end_link = lst_num[a]
                while doc[end_link] != ' ':
                    end_link = end_link + 1
                if not check:
                    check.append([lst_num[a], end_link])
                    print_item(item, lst_num[a], end_link, doc[lst_num[a]:end_link])
                    #print str(lst_num[a]) + ' till ' + str(end_link)
                t = 1
                for ch in check:
                    if lst_num[a] >= ch[0] and end_link <= ch[1]:
                        t = 0
                if t:
                    check.append([lst_num[a], end_link])
                    print_item(item, lst_num[a], end_link, doc[lst_num[a]:end_link])
                    #print str(lst_num[a]) + ' till ' + str(end_link)
                last_num = num
                num = num + 1 + norm_doc[num + 1:].find(' ' + item[0] + ' ')
        print '</file>'
        if max_files > -1:
            if af == max_files:
                break

# Close out_file
out_file.close()
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <file name:"all_TEX/2011_1_5.tex">
# 	<item>
# 		<term>положительный оператор</term>
# 		<link>http://libmeta.ru/concept/show/1393</link>
# 		<link>http://libmeta.ru/concept/1393</link>
# 		<startpos>28795</startpos>
# 		<endpos>28816</endpos>
# 		<linktext>положительный оператор<linktext>
# 	</item>
# 	<item>
# 		<term>векторная решетка</term>
# 		<link>http://libmeta.ru/concept/show/6454</link>
# 		<link>http://libmeta.ru/concept/6454</link>
# 		<startpos>28751</startpos>
# 		<endpos>28767</endpos>
# 		<linktext>векторная решетка<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>674</startpos>
# 		<endpos>683</endpos>
# 		<linktext>операторов<linktext>
# 	</item>
# 	<item>
# 		<term>неравенство</term>
# 		<link>http://libmeta.ru/concept/show/2086</link>
# 		<link>http://libmeta.ru/concept/2086</link>
# 		<startpos>28416</startpos>
# 		<endpos>28426</endpos>
# 		<linktext>НЕРАВЕНСТВО<linktext>
# 	</item>
# 	<item>
# 		<term>неравенство</term>
# 		<link>http://libmeta.ru/concept/show/2086</link>
# 		<link>http://libmeta.ru/concept/2086</link>
# 		<startpos>28582</startpos>
# 		<endpos>28592</endpos>
# 		<linktext>неравенство<linktext>
# 	</item>
# 	<item>
# 		<term>гомоморфизм</term>
# 		<link>http://libmeta.ru/concept/show/3211</link>
# 		<link>http://libmeta.ru/concept/3211</link>
# 		<startpos>28781</startpos>
# 		<endpos>28791</endpos>
# 		<linktext>гомоморфизм<linktext>
# 	</item>
# </file>
# <file name:"all_TEX/2010_3_2.tex">
# 	<item>
# 		<term>необходимые и достаточные условия</term>
# 		<link>http://libmeta.ru/concept/show/4482</link>
# 		<link>http://libmeta.ru/concept/4482</link>
# 		<startpos>641</startpos>
# 		<endpos>666</endpos>
# 		<linktext>необходимые и достаточные <linktext>
# 	</item>
# 	<item>
# 		<term>стационарной фазы метод</term>
# 		<link>http://libmeta.ru/concept/show/3261</link>
# 		<link>http://libmeta.ru/concept/3261</link>
# 		<startpos>2207</startpos>
# 		<endpos>2226</endpos>
# 		<linktext>метода  стационарной<linktext>
# 	</item>
# 	<item>
# 		<term>локально интегрируемая функция</term>
# 		<link>http://libmeta.ru/concept/show/5154</link>
# 		<link>http://libmeta.ru/concept/5154</link>
# 		<startpos>4207</startpos>
# 		<endpos>4229</endpos>
# 		<linktext>локально  интегрируемых<linktext>
# 	</item>
# 	<item>
# 		<term>обобщенных функций пространство</term>
# 		<link>http://libmeta.ru/concept/show/1021</link>
# 		<link>http://libmeta.ru/concept/1021</link>
# 		<startpos>3359</startpos>
# 		<endpos>3389</endpos>
# 		<linktext>пространство обобщенных функций<linktext>
# 	</item>
# 	<item>
# 		<term>бесселя функции</term>
# 		<link>http://libmeta.ru/concept/show/2614</link>
# 		<link>http://libmeta.ru/concept/2614</link>
# 		<startpos>6702</startpos>
# 		<endpos>6716</endpos>
# 		<linktext>функции Бесселя<linktext>
# 	</item>
# 	<item>
# 		<term>ганкеля функции</term>
# 		<link>http://libmeta.ru/concept/show/2611</link>
# 		<link>http://libmeta.ru/concept/2611</link>
# 		<startpos>6812</startpos>
# 		<endpos>6826</endpos>
# 		<linktext>функции Ганкеля<linktext>
# 	</item>
# 	<item>
# 		<term>гладкая функция</term>
# 		<link>http://libmeta.ru/concept/show/2610</link>
# 		<link>http://libmeta.ru/concept/2610</link>
# 		<startpos>1609</startpos>
# 		<endpos>1623</endpos>
# 		<linktext>гладкая функция<linktext>
# 	</item>
# 	<item>
# 		<term>гладкая функция</term>
# 		<link>http://libmeta.ru/concept/show/2610</link>
# 		<link>http://libmeta.ru/concept/2610</link>
# 		<startpos>3321</startpos>
# 		<endpos>3335</endpos>
# 		<linktext>гладких функций<linktext>
# 	</item>
# 	<item>
# 		<term>перевала метод</term>
# 		<link>http://libmeta.ru/concept/show/3263</link>
# 		<link>http://libmeta.ru/concept/3263</link>
# 		<startpos>27336</startpos>
# 		<endpos>27349</endpos>
# 		<linktext>Метод перевала<linktext>
# 	</item>
# 	<item>
# 		<term>плотное множество</term>
# 		<link>http://libmeta.ru/concept/show/3762</link>
# 		<link>http://libmeta.ru/concept/3762</link>
# 		<startpos>4070</startpos>
# 		<endpos>4087</endpos>
# 		<linktext>плотного множества<linktext>
# 	</item>
# 	<item>
# 		<term>обобщенная функция</term>
# 		<link>http://libmeta.ru/concept/show/4264</link>
# 		<link>http://libmeta.ru/concept/4264</link>
# 		<startpos>1027</startpos>
# 		<endpos>1044</endpos>
# 		<linktext>обобщенная функция<linktext>
# 	</item>
# 	<item>
# 		<term>обобщенная функция</term>
# 		<link>http://libmeta.ru/concept/show/4264</link>
# 		<link>http://libmeta.ru/concept/4264</link>
# 		<startpos>5232</startpos>
# 		<endpos>5249</endpos>
# 		<linktext>обобщенных функций<linktext>
# 	</item>
# 	<item>
# 		<term>интегрируемая функция</term>
# 		<link>http://libmeta.ru/concept/show/6363</link>
# 		<link>http://libmeta.ru/concept/6363</link>
# 		<startpos>4217</startpos>
# 		<endpos>4237</endpos>
# 		<linktext>интегрируемых функций<linktext>
# 	</item>
# 	<item>
# 		<term>асимптотическое разложение</term>
# 		<link>http://libmeta.ru/concept/show/6528</link>
# 		<link>http://libmeta.ru/concept/6528</link>
# 		<startpos>6675</startpos>
# 		<endpos>6700</endpos>
# 		<linktext>асимптотическое разложение<linktext>
# 	</item>
# 	<item>
# 		<term>асимптотическое разложение</term>
# 		<link>http://libmeta.ru/concept/show/6528</link>
# 		<link>http://libmeta.ru/concept/6528</link>
# 		<startpos>7716</startpos>
# 		<endpos>7741</endpos>
# 		<linktext>Асимптотическое разложение<linktext>
# 	</item>
# 	<item>
# 		<term>фурье преобразование</term>
# 		<link>http://libmeta.ru/concept/show/1009</link>
# 		<link>http://libmeta.ru/concept/1009</link>
# 		<startpos>3138</startpos>
# 		<endpos>3157</endpos>
# 		<linktext>преобразование Фурье<linktext>
# 	</item>
# 	<item>
# 		<term>фурье преобразование</term>
# 		<link>http://libmeta.ru/concept/show/1009</link>
# 		<link>http://libmeta.ru/concept/1009</link>
# 		<startpos>3248</startpos>
# 		<endpos>3267</endpos>
# 		<linktext>преобразование Фурье<linktext>
# 	</item>
# 	<item>
# 		<term>фурье преобразование</term>
# 		<link>http://libmeta.ru/concept/show/1009</link>
# 		<link>http://libmeta.ru/concept/1009</link>
# 		<startpos>19691</startpos>
# 		<endpos>19710</endpos>
# 		<linktext>Преобразование Фурье<linktext>
# 	</item>
# 	<item>
# 		<term>доказательство</term>
# 		<link>http://libmeta.ru/concept/show/1208</link>
# 		<link>http://libmeta.ru/concept/1208</link>
# 		<startpos>1886</startpos>
# 		<endpos>1899</endpos>
# 		<linktext>доказательстве<linktext>
# 	</item>
# 	<item>
# 		<term>доказательство</term>
# 		<link>http://libmeta.ru/concept/show/1208</link>
# 		<link>http://libmeta.ru/concept/1208</link>
# 		<startpos>4538</startpos>
# 		<endpos>4551</endpos>
# 		<linktext>доказательстве<linktext>
# 	</item>
# 	<item>
# 		<term>доказательство</term>
# 		<link>http://libmeta.ru/concept/show/1208</link>
# 		<link>http://libmeta.ru/concept/1208</link>
# 		<startpos>7812</startpos>
# 		<endpos>7825</endpos>
# 		<linktext>доказательства<linktext>
# 	</item>
# 	<item>
# 		<term>доказательство</term>
# 		<link>http://libmeta.ru/concept/show/1208</link>
# 		<link>http://libmeta.ru/concept/1208</link>
# 		<startpos>10147</startpos>
# 		<endpos>10160</endpos>
# 		<linktext>доказательства<linktext>
# 	</item>
# 	<item>
# 		<term>доказательство</term>
# 		<link>http://libmeta.ru/concept/show/1208</link>
# 		<link>http://libmeta.ru/concept/1208</link>
# 		<startpos>18229</startpos>
# 		<endpos>18242</endpos>
# 		<linktext>доказательства<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>79</startpos>
# 		<endpos>88</endpos>
# 		<linktext>ОПЕРАТОРОВ<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>176</startpos>
# 		<endpos>185</endpos>
# 		<linktext>операторов<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>703</startpos>
# 		<endpos>712</endpos>
# 		<linktext>операторов<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>1047</startpos>
# 		<endpos>1054</endpos>
# 		<linktext>оператор<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>1218</startpos>
# 		<endpos>1226</endpos>
# 		<linktext>оператора<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>1654</startpos>
# 		<endpos>1662</endpos>
# 		<linktext>оператора<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>2078</startpos>
# 		<endpos>2087</endpos>
# 		<linktext>операторов<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>2625</startpos>
# 		<endpos>2634</endpos>
# 		<linktext>операторов<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>2698</startpos>
# 		<endpos>2705</endpos>
# 		<linktext>оператор<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>2732</startpos>
# 		<endpos>2739</endpos>
# 		<linktext>оператор<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>8519</startpos>
# 		<endpos>8527</endpos>
# 		<linktext>оператора<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>9185</startpos>
# 		<endpos>9192</endpos>
# 		<linktext>оператор<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>17355</startpos>
# 		<endpos>17363</endpos>
# 		<linktext>оператора<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>18308</startpos>
# 		<endpos>18316</endpos>
# 		<linktext>оператора<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>18685</startpos>
# 		<endpos>18693</endpos>
# 		<linktext>оператора<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>18864</startpos>
# 		<endpos>18872</endpos>
# 		<linktext>оператора<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>19071</startpos>
# 		<endpos>19078</endpos>
# 		<linktext>оператор<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>19580</startpos>
# 		<endpos>19587</endpos>
# 		<linktext>оператор<linktext>
# 	</item>
# 	<item>
# 		<term>оператор</term>
# 		<link>http://libmeta.ru/concept/show/1663</link>
# 		<link>http://libmeta.ru/concept/1663</link>
# 		<startpos>25659</startpos>
# 		<endpos>25667</endpos>
# 		<linktext>оператора<linktext>
# 	</item>
# 	<item>
# 		<term>потенциал</term>
# 		<link>http://libmeta.ru/concept/show/1776</link>
# 		<link>http://libmeta.ru/concept/1776</link>
# 		<startpos>192</startpos>
# 		<endpos>201</endpos>
# 		<linktext>потенциала<linktext>
# 	</item>
# 	<item>
# 		<term>потенциал</term>
# 		<link>http://libmeta.ru/concept/show/1776</link>
# 		<link>http://libmeta.ru/concept/1776</link>
# 		<startpos>719</startpos>
# 		<endpos>728</endpos>
# 		<linktext>потенциала<linktext>
# 	</item>
# 	<item>
# 		<term>потенциал</term>
# 		<link>http://libmeta.ru/concept/show/1776</link>
# 		<link>http://libmeta.ru/concept/1776</link>
# 		<startpos>1061</startpos>
# 		<endpos>1070</endpos>
# 		<linktext>потенциала<linktext>
# 	</item>
# 	<item>
# 		<term>схема</term>
# 		<link>http://libmeta.ru/concept/show/2009</link>
# 		<link>http://libmeta.ru/concept/2009</link>
# 		<startpos>10141</startpos>
# 		<endpos>10145</endpos>
# 		<linktext>схему<linktext>
# 	</item>
# 	<item>
# 		<term>неравенство</term>
# 		<link>http://libmeta.ru/concept/show/2086</link>
# 		<link>http://libmeta.ru/concept/2086</link>
# 		<startpos>4589</startpos>
# 		<endpos>4599</endpos>
# 		<linktext>неравенство<linktext>
# 	</item>
# 	<item>
# 		<term>неравенство</term>
# 		<link>http://libmeta.ru/concept/show/2086</link>
# 		<link>http://libmeta.ru/concept/2086</link>
# 		<startpos>10842</startpos>
# 		<endpos>10852</endpos>
# 		<linktext>неравенство<linktext>
# 	</item>
# 	<item>
# 		<term>неравенство</term>
# 		<link>http://libmeta.ru/concept/show/2086</link>
# 		<link>http://libmeta.ru/concept/2086</link>
# 		<startpos>17796</startpos>
# 		<endpos>17806</endpos>
# 		<linktext>неравенство<linktext>
# 	</item>
# 	<item>
# 		<term>бесконечность</term>
# 		<link>http://libmeta.ru/concept/show/2133</link>
# 		<link>http://libmeta.ru/concept/2133</link>
# 		<startpos>1838</startpos>
# 		<endpos>1850</endpos>
# 		<linktext>бесконечности<linktext>
# 	</item>
# 	<item>
# 		<term>интеграл</term>
# 		<link>http://libmeta.ru/concept/show/2483</link>
# 		<link>http://libmeta.ru/concept/2483</link>
# 		<startpos>2113</startpos>
# 		<endpos>2122</endpos>
# 		<linktext>интегралов<linktext>
# 	</item>
# 	<item>
# 		<term>интеграл</term>
# 		<link>http://libmeta.ru/concept/show/2483</link>
# 		<link>http://libmeta.ru/concept/2483</link>
# 		<startpos>2196</startpos>
# 		<endpos>2205</endpos>
# 		<linktext>интегралам<linktext>
# 	</item>
# 	<item>
# 		<term>интеграл</term>
# 		<link>http://libmeta.ru/concept/show/2483</link>
# 		<link>http://libmeta.ru/concept/2483</link>
# 		<startpos>7753</startpos>
# 		<endpos>7762</endpos>
# 		<linktext>интегралов<linktext>
# 	</item>
# 	<item>
# 		<term>интеграл</term>
# 		<link>http://libmeta.ru/concept/show/2483</link>
# 		<link>http://libmeta.ru/concept/2483</link>
# 		<startpos>22585</startpos>
# 		<endpos>22592</endpos>
# 		<linktext>интеграл<linktext>
# 	</item>
# 	<item>
# 		<term>теория</term>
# 		<link>http://libmeta.ru/concept/show/2186</link>
# 		<link>http://libmeta.ru/concept/2186</link>
# 		<startpos>27248</startpos>
# 		<endpos>27253</endpos>
# 		<linktext>Теория<linktext>
# 	</item>
# 	<item>
# 		<term>уравнение</term>
# 		<link>http://libmeta.ru/concept/show/2257</link>
# 		<link>http://libmeta.ru/concept/2257</link>
# 		<startpos>27584</startpos>
# 		<endpos>27592</endpos>
# 		<linktext>уравнений<linktext>
# 	</item>
# 	<item>
# 		<term>уравнение</term>
# 		<link>http://libmeta.ru/concept/show/2257</link>
# 		<link>http://libmeta.ru/concept/2257</link>
# 		<startpos>27816</startpos>
# 		<endpos>27824</endpos>
# 		<linktext>уравнений<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>3159</startpos>
# 		<endpos>3165</endpos>
# 		<linktext>функции<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>3459</startpos>
# 		<endpos>3465</endpos>
# 		<linktext>функций<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>6417</startpos>
# 		<endpos>6423</endpos>
# 		<linktext>функция<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>9783</startpos>
# 		<endpos>9789</endpos>
# 		<linktext>функция<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>10411</startpos>
# 		<endpos>10417</endpos>
# 		<linktext>функция<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>14091</startpos>
# 		<endpos>14097</endpos>
# 		<linktext>функция<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>16829</startpos>
# 		<endpos>16835</endpos>
# 		<linktext>функция<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>20225</startpos>
# 		<endpos>20231</endpos>
# 		<linktext>функция<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>20941</startpos>
# 		<endpos>20947</endpos>
# 		<linktext>функция<linktext>
# 	</item>
# 	<item>
# 		<term>функция</term>
# 		<link>http://libmeta.ru/concept/show/2436</link>
# 		<link>http://libmeta.ru/concept/2436</link>
# 		<startpos>27267</startpos>
# 		<endpos>27273</endpos>
# 		<linktext>функций<linktext>
# 	</item>
# 	<item>
# 		<term>пространство</term>
# 		<link>http://libmeta.ru/concept/show/2504</link>
# 		<link>http://libmeta.ru/concept/2504</link>
# 		<startpos>3446</startpos>
# 		<endpos>3457</endpos>
# 		<linktext>пространства<linktext>
# 	</item>
# 	<item>
# 		<term>пространство</term>
# 		<link>http://libmeta.ru/concept/show/2504</link>
# 		<link>http://libmeta.ru/concept/2504</link>
# 		<startpos>4455</startpos>
# 		<endpos>4466</endpos>
# 		<linktext>пространство<linktext>
# 	</item>
# 	<item>
# 		<term>пространство</term>
# 		<link>http://libmeta.ru/concept/show/2504</link>
# 		<link>http://libmeta.ru/concept/2504</link>
# 		<startpos>4853</startpos>
# 		<endpos>4863</endpos>
# 		<linktext>пространств<linktext>
# 	</item>
# 	<item>
# 		<term>пространство</term>
# 		<link>http://libmeta.ru/concept/show/2504</link>
# 		<link>http://libmeta.ru/concept/2504</link>
# 		<startpos>4961</startpos>
# 		<endpos>4972</endpos>
# 		<linktext>пространство<linktext>
# 	</item>
# 	<item>
# 		<term>пространство</term>
# 		<link>http://libmeta.ru/concept/show/2504</link>
# 		<link>http://libmeta.ru/concept/2504</link>
# 		<startpos>18526</startpos>
# 		<endpos>18537</endpos>
# 		<linktext>пространстве<linktext>
# 	</item>
# 	<item>
# 		<term>пространство</term>
# 		<link>http://libmeta.ru/concept/show/2504</link>
# 		<link>http://libmeta.ru/concept/2504</link>
# 		<startpos>18603</startpos>
# 		<endpos>18614</endpos>
# 		<linktext>пространстве<linktext>
# 	</item>
# 	<item>
# 		<term>пространство</term>
# 		<link>http://libmeta.ru/concept/show/2504</link>
# 		<link>http://libmeta.ru/concept/2504</link>
# 		<startpos>25192</startpos>
# 		<endpos>25203</endpos>
# 		<linktext>пространстве<linktext>
# 	</item>
# 	<item>
# 		<term>сдвиг</term>
# 		<link>http://libmeta.ru/concept/show/2590</link>
# 		<link>http://libmeta.ru/concept/2590</link>
# 		<startpos>25239</startpos>
# 		<endpos>25244</endpos>
# 		<linktext>сдвига<linktext>
# 	</item>
# 	<item>
# 		<term>множество</term>
# 		<link>http://libmeta.ru/concept/show/2666</link>
# 		<link>http://libmeta.ru/concept/2666</link>
# 		<startpos>3540</startpos>
# 		<endpos>3548</endpos>
# 		<linktext>множество<linktext>
# 	</item>
# 	<item>
# 		<term>множество</term>
# 		<link>http://libmeta.ru/concept/show/2666</link>
# 		<link>http://libmeta.ru/concept/2666</link>
# 		<startpos>4192</startpos>
# 		<endpos>4200</endpos>
# 		<linktext>множество<linktext>
# 	</item>
# 	<item>
# 		<term>множество</term>
# 		<link>http://libmeta.ru/concept/show/2666</link>
# 		<link>http://libmeta.ru/concept/2666</link>
# 		<startpos>5222</startpos>
# 		<endpos>5230</endpos>
# 		<linktext>множество<linktext>
# 	</item>
# 	<item>
# 		<term>множество</term>
# 		<link>http://libmeta.ru/concept/show/2666</link>
# 		<link>http://libmeta.ru/concept/2666</link>
# 		<startpos>8616</startpos>
# 		<endpos>8624</endpos>
# 		<linktext>множество<linktext>
# 	</item>
# 	<item>
# 		<term>множество</term>
# 		<link>http://libmeta.ru/concept/show/2666</link>
# 		<link>http://libmeta.ru/concept/2666</link>
# 		<startpos>8849</startpos>
# 		<endpos>8857</endpos>
# 		<linktext>множество<linktext>
# 	</item>
# 	<item>
# 		<term>сфера</term>
# 		<link>http://libmeta.ru/concept/show/2814</link>
# 		<link>http://libmeta.ru/concept/2814</link>
# 		<startpos>775</startpos>
# 		<endpos>779</endpos>
# 		<linktext>сфере<linktext>
# 	</item>
# 	<item>
# 		<term>теорема</term>
# 		<link>http://libmeta.ru/concept/show/3042</link>
# 		<link>http://libmeta.ru/concept/3042</link>
# 		<startpos>1918</startpos>
# 		<endpos>1923</endpos>
# 		<linktext>теорем<linktext>
# 	</item>
# 	<item>
# 		<term>теорема</term>
# 		<link>http://libmeta.ru/concept/show/3042</link>
# 		<link>http://libmeta.ru/concept/3042</link>
# 		<startpos>5812</startpos>
# 		<endpos>5818</endpos>
# 		<linktext>теоремы<linktext>
# 	</item>
# 	<item>
# 		<term>класс</term>
# 		<link>http://libmeta.ru/concept/show/3047</link>
# 		<link>http://libmeta.ru/concept/3047</link>
# 		<startpos>3290</startpos>
# 		<endpos>3294</endpos>
# 		<linktext>класс<linktext>
# 	</item>
# 	<item>
# 		<term>класс</term>
# 		<link>http://libmeta.ru/concept/show/3047</link>
# 		<link>http://libmeta.ru/concept/3047</link>
# 		<startpos>4012</startpos>
# 		<endpos>4016</endpos>
# 		<linktext>класс<linktext>
# 	</item>
# 	<item>
# 		<term>класс</term>
# 		<link>http://libmeta.ru/concept/show/3047</link>
# 		<link>http://libmeta.ru/concept/3047</link>
# 		<startpos>6425</startpos>
# 		<endpos>6430</endpos>
# 		<linktext>класса<linktext>
# 	</item>
# 	<item>
# 		<term>вид</term>
# 		<link>http://libmeta.ru/concept/show/3150</link>
# 		<link>http://libmeta.ru/concept/3150</link>
# 		<startpos>2092</startpos>
# 		<endpos>2095</endpos>
# 		<linktext>виде<linktext>
# 	</item>
# 	<item>
# 		<term>вид</term>
# 		<link>http://libmeta.ru/concept/show/3150</link>
# 		<link>http://libmeta.ru/concept/3150</link>
# 		<startpos>6786</startpos>
# 		<endpos>6789</endpos>
# 		<linktext>виде<linktext>
# 	</item>
# 	<item>
# 		<term>вид</term>
# 		<link>http://libmeta.ru/concept/show/3150</link>
# 		<link>http://libmeta.ru/concept/3150</link>
# 		<startpos>9218</startpos>
# 		<endpos>9221</endpos>
# 		<linktext>виде<linktext>
# 	</item>
# 	<item>
# 		<term>вид</term>
# 		<link>http://libmeta.ru/concept/show/3150</link>
# 		<link>http://libmeta.ru/concept/3150</link>
# 		<startpos>11612</startpos>
# 		<endpos>11615</endpos>
# 		<linktext>виде<linktext>
# 	</item>
# 	<item>
# 		<term>вид</term>
# 		<link>http://libmeta.ru/concept/show/3150</link>
# 		<link>http://libmeta.ru/concept/3150</link>
# 		<startpos>19978</startpos>
# 		<endpos>19981</endpos>
# 		<linktext>виде<linktext>
# 	</item>
# 	<item>
# 		<term>особенность</term>
# 		<link>http://libmeta.ru/concept/show/3378</link>
# 		<link>http://libmeta.ru/concept/3378</link>
# 		<startpos>750</startpos>
# 		<endpos>760</endpos>
# 		<linktext>особенности<linktext>
# 	</item>
# 	<item>
# 		<term>норма</term>
# 		<link>http://libmeta.ru/concept/show/3728</link>
# 		<link>http://libmeta.ru/concept/3728</link>
# 		<startpos>25184</startpos>
# 		<endpos>25188</endpos>
# 		<linktext>нормы<linktext>
# 	</item>
# 	<item>
# 		<term>шар</term>
# 		<link>http://libmeta.ru/concept/show/3977</link>
# 		<link>http://libmeta.ru/concept/3977</link>
# 		<startpos>4413</startpos>
# 		<endpos>4417</endpos>
# 		<linktext>шарам<linktext>
# 	</item>
# 	<item>
# 		<term>программа</term>
# 		<link>http://libmeta.ru/concept/show/4557</link>
# 		<link>http://libmeta.ru/concept/4557</link>
# 		<startpos>516</startpos>
# 		<endpos>524</endpos>
# 		<linktext>программы<linktext>
# 	</item>
# 	<item>
# 		<term>выпуклость</term>
# 		<link>http://libmeta.ru/concept/show/4704</link>
# 		<link>http://libmeta.ru/concept/4704</link>
# 		<startpos>12545</startpos>
# 		<endpos>12554</endpos>
# 		<linktext>выпуклости<linktext>
# 	</item>
# 	<item>
# 		<term>выпуклость</term>
# 		<link>http://libmeta.ru/concept/show/4704</link>
# 		<link>http://libmeta.ru/concept/4704</link>
# 		<startpos>18110</startpos>
# 		<endpos>18119</endpos>
# 		<linktext>выпуклости<linktext>
# 	</item>
# 	<item>
# 		<term>распределение</term>
# 		<link>http://libmeta.ru/concept/show/4820</link>
# 		<link>http://libmeta.ru/concept/4820</link>
# 		<startpos>3469</startpos>
# 		<endpos>3481</endpos>
# 		<linktext>распределений<linktext>
# 	</item>
# 	<item>
# 		<term>мультипликаторы</term>
# 		<link>http://libmeta.ru/concept/show/6191</link>
# 		<link>http://libmeta.ru/concept/6191</link>
# 		<startpos>1011</startpos>
# 		<endpos>1024</endpos>
# 		<linktext>мультипликатор<linktext>
# 	</item>
# 	<item>
# 		<term>мультипликаторы</term>
# 		<link>http://libmeta.ru/concept/show/6191</link>
# 		<link>http://libmeta.ru/concept/6191</link>
# 		<startpos>2277</startpos>
# 		<endpos>2292</endpos>
# 		<linktext>мультипликаторов<linktext>
# 	</item>
# 	<item>
# 		<term>мультипликаторы</term>
# 		<link>http://libmeta.ru/concept/show/6191</link>
# 		<link>http://libmeta.ru/concept/6191</link>
# 		<startpos>5766</startpos>
# 		<endpos>5781</endpos>
# 		<linktext>мультипликаторах<linktext>
# 	</item>
# 	<item>
# 		<term>мультипликаторы</term>
# 		<link>http://libmeta.ru/concept/show/6191</link>
# 		<link>http://libmeta.ru/concept/6191</link>
# 		<startpos>10501</startpos>
# 		<endpos>10516</endpos>
# 		<linktext>мультипликатором<linktext>
# 	</item>
# 	<item>
# 		<term>мультипликаторы</term>
# 		<link>http://libmeta.ru/concept/show/6191</link>
# 		<link>http://libmeta.ru/concept/6191</link>
# 		<startpos>15209</startpos>
# 		<endpos>15224</endpos>
# 		<linktext>мультипликатором<linktext>
# 	</item>
# 	<item>
# 		<term>мультипликаторы</term>
# 		<link>http://libmeta.ru/concept/show/6191</link>
# 		<link>http://libmeta.ru/concept/6191</link>
# 		<startpos>16847</startpos>
# 		<endpos>16862</endpos>
# 		<linktext>мультипликатором<linktext>
# 	</item>
# 	<item>
# 		<term>ядро</term>
# 		<link>http://libmeta.ru/concept/show/745</link>
# 		<link>http://libmeta.ru/concept/745</link>
# 		<startpos>732</startpos>
# 		<endpos>737</endpos>
# 		<linktext>ядрами<linktext>
# 	</item>
# 	<item>
# 		<term>ядро</term>
# 		<link>http://libmeta.ru/concept/show/745</link>
# 		<link>http://libmeta.ru/concept/745</link>
# 		<startpos>17350</startpos>
# 		<endpos>17353</endpos>
# 		<linktext>ядро<linktext>
# 	</item>
# 	<item>
# 		<term>ядро</term>
# 		<link>http://libmeta.ru/concept/show/745</link>
# 		<link>http://libmeta.ru/concept/745</link>
# 		<startpos>19712</startpos>
# 		<endpos>19715</endpos>
# 		<linktext>ядра<linktext>
# 	</item>
# 	<item>
# 		<term>формула</term>
# 		<link>http://libmeta.ru/concept/show/868</link>
# 		<link>http://libmeta.ru/concept/868</link>
# 		<startpos>12635</startpos>
# 		<endpos>12641</endpos>
# 		<linktext>формулу<linktext>
# 	</item>
# 	<item>
# 		<term>характеристика</term>
# 		<link>http://libmeta.ru/concept/show/962</link>
# 		<link>http://libmeta.ru/concept/962</link>
# 		<startpos>1637</startpos>
# 		<endpos>1651</endpos>
# 		<linktext>характеристикой<linktext>
# 	</item>
# 	<item>
# 		<term>свертка</term>
# 		<link>http://libmeta.ru/concept/show/1020</link>
# 		<link>http://libmeta.ru/concept/1020</link>
# 		<startpos>1228</startpos>
# 		<endpos>1234</endpos>
# 		<linktext>свертки<linktext>
# 	</item>
# 	<item>
# 		<term>свертка</term>
# 		<link>http://libmeta.ru/concept/show/1020</link>
# 		<link>http://libmeta.ru/concept/1020</link>
# 		<startpos>2741</startpos>
# 		<endpos>2747</endpos>
# 		<linktext>свертки<linktext>
# 	</item>
# 	<item>
# 		<term>экспонента</term>
# 		<link>http://libmeta.ru/concept/show/1152</link>
# 		<link>http://libmeta.ru/concept/1152</link>
# 		<startpos>2151</startpos>
# 		<endpos>2160</endpos>
# 		<linktext>экспоненту<linktext>
# 	</item>
# 	<item>
# 		<term>экспонента</term>
# 		<link>http://libmeta.ru/concept/show/1152</link>
# 		<link>http://libmeta.ru/concept/1152</link>
# 		<startpos>7791</startpos>
# 		<endpos>7800</endpos>
# 		<linktext>экспоненту<linktext>
# 	</item>
# </file>
